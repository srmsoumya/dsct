# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Set display
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
plt.style.use('ggplot')

# %%
DATA = Path('data')
# !ls {DATA}
# Out:
# data_description.txt  features.txt  Poll.docx  train.csv

# %% [markdown]
# # Structural EDA

# %%
# Read data

df = pd.read_csv(DATA/'train.csv')
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# Feature Selection

features = ['LotArea', 'LotFrontage', 'GarageArea', 'YearBuilt', 'MSZoning', 'Utilities', 'BldgType', 'HouseStyle', 'OverallCond', 'KitchenQual', 'PoolQC', 'Neighborhood', 'CentralAir', 'SalePrice']
df2 = df[features] 
df2.head()
# Out:
#    LotArea  LotFrontage  GarageArea  YearBuilt MSZoning Utilities BldgType  \
# 0     8450         65.0         548       2003       RL    AllPub     1Fam
# 1     9600         80.0         460       1976       RL    AllPub     1Fam
# 2    11250         68.0         608       2001       RL    AllPub     1Fam
# 3     9550         60.0         642       1915       RL    AllPub     1Fam
# 4    14260         84.0         836       2000       RL    AllPub     1Fam
#
#   HouseStyle  OverallCond KitchenQual PoolQC Neighborhood CentralAir  \
# 0     2Story            5          Gd    NaN      CollgCr          Y
# 1     1Story            8          TA    NaN      Veenker          Y
# 2     2Story            5          Gd    NaN      CollgCr          Y
# 3     2Story            5          Gd    NaN      Crawfor          Y
# 4     2Story            5          Gd    NaN      NoRidge          Y
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
# Rename columns

df2.columns = ['area', 'street_length', 'garage_area', 'year', 'zone', 'utils', 'type', 'style', 'overall', 'kitchen', 'pool', 'hood', 'ac', 'price']
df2.head()
# Out:
#     area  street_length  garage_area  year zone   utils  type   style  \
# 0   8450           65.0          548  2003   RL  AllPub  1Fam  2Story
# 1   9600           80.0          460  1976   RL  AllPub  1Fam  1Story
# 2  11250           68.0          608  2001   RL  AllPub  1Fam  2Story
# 3   9550           60.0          642  1915   RL  AllPub  1Fam  2Story
# 4  14260           84.0          836  2000   RL  AllPub  1Fam  2Story
#
#    overall kitchen pool     hood ac   price
# 0        5      Gd  NaN  CollgCr  Y  208500
# 1        8      TA  NaN  Veenker  Y  181500
# 2        5      Gd  NaN  CollgCr  Y  223500
# 3        5      Gd  NaN  Crawfor  Y  140000
# 4        5      Gd  NaN  NoRidge  Y  250000

# %%
# Look at the data distribution

df2.describe(include='number')
# Out:
#                 area  street_length  garage_area         year      overall  \
# count    1460.000000    1201.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082      70.049958   472.980137  1971.267808     5.575342
# std      9981.264932      24.284752   213.804841    30.202904     1.112799
# min      1300.000000      21.000000     0.000000  1872.000000     1.000000
# 25%      7553.500000      59.000000   334.500000  1954.000000     5.000000
# 50%      9478.500000      69.000000   480.000000  1973.000000     5.000000
# 75%     11601.500000      80.000000   576.000000  2000.000000     6.000000
# max    215245.000000     313.000000  1418.000000  2010.000000     9.000000
#
#                price
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
df2.describe(include='object')
# Out:
#         zone   utils  type   style kitchen pool   hood    ac
# count   1460    1460  1460    1460    1460    7   1460  1460
# unique     5       2     5       8       4    3     25     2
# top       RL  AllPub  1Fam  1Story      TA   Gd  NAmes     Y
# freq    1151    1459  1220     726     735    3    225  1365

# %%
# Drop columns

df3 = df2.drop(labels=['pool', 'utils'], axis=1) 
df3.head()
# Out:
#     area  street_length  garage_area  year zone  type   style  overall  \
# 0   8450           65.0          548  2003   RL  1Fam  2Story        5
# 1   9600           80.0          460  1976   RL  1Fam  1Story        8
# 2  11250           68.0          608  2001   RL  1Fam  2Story        5
# 3   9550           60.0          642  1915   RL  1Fam  2Story        5
# 4  14260           84.0          836  2000   RL  1Fam  2Story        5
#
#   kitchen     hood ac   price
# 0      Gd  CollgCr  Y  208500
# 1      TA  Veenker  Y  181500
# 2      Gd  CollgCr  Y  223500
# 3      Gd  Crawfor  Y  140000
# 4      Gd  NoRidge  Y  250000

# %%
# Fix data types

df3.dtypes
# Out:
# area               int64
# street_length    float64
# garage_area        int64
# year               int64
# zone              object
# type              object
# style             object
# overall            int64
# kitchen           object
# hood              object
# ac                object
# price              int64
# dtype: object

# %%
# Fix types

df3 = df3.assign(**{c:pd.Categorical(df3[c]) for c in df3.select_dtypes('object').columns})
df3.dtypes
# Out:
# area                int64
# street_length     float64
# garage_area         int64
# year                int64
# zone             category
# type             category
# style            category
# overall             int64
# kitchen          category
# hood             category
# ac               category
# price               int64
# dtype: object

# %%
# Remove outliers

def iqr(df, c):
    return df[c].quantile(q=0.75) - df[c].quantile(q=0.25)

# Outlier > 75th %tile + 1.5IQR & < 25th %tile - 1.5IQR
def outlier_count(df, c):
    upper_bound = df[c].quantile(q=0.75) + 1.5 * iqr(df, c)
    lower_bound = df[c].quantile(q=0.25) - 1.5 * iqr(df, c)

    return len(df[df[c] > upper_bound]) + len(df[df[c] < lower_bound])

# Outlier > 75th %tile + 1.5IQR & < 25th %tile - 1.5IQR
def remove_outlier(df, c):
    upper_bound = df[c].quantile(q=0.75) + 1.5 * iqr(df, c)
    lower_bound = df[c].quantile(q=0.25) - 1.5 * iqr(df, c)
    
    return df[(df[c] <= upper_bound) & (df[c] >= lower_bound)]

# %%
for c in df3.select_dtypes('number'): print(f'{c}: {outlier_count(df3, c)}')
# Out:
# area: 69
# street_length: 88
# garage_area: 21
# year: 7
# overall: 125
# price: 61

# %%
df4 = remove_outlier(remove_outlier(df3, 'price'), 'area')

# %%
clean_df = df4.copy()
clean_df.head()
# Out:
#     area  street_length  garage_area  year zone  type   style  overall  \
# 0   8450           65.0          548  2003   RL  1Fam  2Story        5
# 1   9600           80.0          460  1976   RL  1Fam  1Story        8
# 2  11250           68.0          608  2001   RL  1Fam  2Story        5
# 3   9550           60.0          642  1915   RL  1Fam  2Story        5
# 4  14260           84.0          836  2000   RL  1Fam  2Story        5
#
#   kitchen     hood ac   price
# 0      Gd  CollgCr  Y  208500
# 1      TA  Veenker  Y  181500
# 2      Gd  CollgCr  Y  223500
# 3      Gd  Crawfor  Y  140000
# 4      Gd  NoRidge  Y  250000

# %%
# fn A -> select features
# fn B -> drop cols
# fn C -> remove_outlier

# C(B(A(df)))

# df -> A -> B -> C -> df

# %% [markdown]
# # Functional EDA

# %%
from temp import *

# %%
features = ['LotArea', 'LotFrontage', 'GarageArea', 'YearBuilt', 'MSZoning', 'Utilities', 'BldgType', 
            'HouseStyle', 'OverallCond', 'KitchenQual', 'PoolQC', 'Neighborhood', 'CentralAir', 'SalePrice']

col_name = {
    'LotArea': 'area',
    'LotFrontage': 'street_len',
    'GarageArea': 'garage',
    'YearBuilt': 'year',
    'MSZoning': 'zone',
    'Utilities': 'utils',
    'BldgType': 'type',
    'HouseStyle': 'style',
    'OverallCond': 'condition',
    'KitchenQual': 'kitchen',
    'PoolQC': 'pool',
    'Neighborhood': 'hood',
    'CentralAir': 'ac',
    'SalePrice': 'price'
}

# col_type = {c:pd.Categorical(df[c]) for c in df.select_dtypes('object').columns}

clean_df = (df
  .pipe(make_copy)
  .pipe(select_features, features)
  .pipe(fix_names, col_name)
  .pipe(drop_cols, ['utils', 'pool'])
  .pipe(fix_types))
# Out:
# Shape: (1460, 81), Execution time: 0.62 ms, Function: make_copy
# Shape: (1460, 14), Execution time: 1.06 ms, Function: select_features
# Shape: (1460, 14), Execution time: 0.91 ms, Function: fix_names
# Shape: (1460, 12), Execution time: 0.65 ms, Function: drop_cols
# Shape: (1460, 12), Execution time: 4.98 ms, Function: fix_types

# %%
clean_df.head()
# Out:
#     area  street_len  garage  year zone  type   style  condition kitchen  \
# 0   8450        65.0     548  2003   RL  1Fam  2Story          5      Gd
# 1   9600        80.0     460  1976   RL  1Fam  1Story          8      TA
# 2  11250        68.0     608  2001   RL  1Fam  2Story          5      Gd
# 3   9550        60.0     642  1915   RL  1Fam  2Story          5      Gd
# 4  14260        84.0     836  2000   RL  1Fam  2Story          5      Gd
#
#       hood ac   price
# 0  CollgCr  Y  208500
# 1  Veenker  Y  181500
# 2  CollgCr  Y  223500
# 3  Crawfor  Y  140000
# 4  NoRidge  Y  250000

# %% [markdown]
# ## Exercise

# %% [markdown]
# Write a function to remove outliers from the DataFrame and add it to the processing pipeline using `pandas pipe`

# %%
# YOUR CODE GOES HERE
@log
def remove_outliers(df, cols=None):
    def iqr(c):
        return df[c].quantile(q=0.75) - df[c].quantile(q=0.25)

    def compute_bounds(c):
        box = iqr(c)
        L = df[c].quantile(q=0.25) - 1.5 * box
        U = df[c].quantile(q=0.75) + 1.5 * box

        return (L,U)
    
    for c in cols:
        L,U = compute_bounds(c)
        df = df.query(f'{c} <= @U and {c} >= @L')
    return df

# %%
clean_df.pipe(remove_outliers, ['area', 'price'])
# Out:
# Shape: (1330, 12), Execution time: 10.92 ms, Function: remove_outliers
#        area  street_len  garage  year zone  type   style  condition kitchen  \
# 0      8450        65.0     548  2003   RL  1Fam  2Story          5      Gd
# 1      9600        80.0     460  1976   RL  1Fam  1Story          8      TA
# 2     11250        68.0     608  2001   RL  1Fam  2Story          5      Gd
# 3      9550        60.0     642  1915   RL  1Fam  2Story          5      Gd
# 4     14260        84.0     836  2000   RL  1Fam  2Story          5      Gd
# ...     ...         ...     ...   ...  ...   ...     ...        ...     ...
# 1455   7917        62.0     460  1999   RL  1Fam  2Story          5      TA
# 1456  13175        85.0     500  1978   RL  1Fam  1Story          6      TA
# 1457   9042        66.0     252  1941   RL  1Fam  2Story          9      Gd
# 1458   9717        68.0     240  1950   RL  1Fam  1Story          6      Gd
# 1459   9937        75.0     276  1965   RL  1Fam  1Story          6      TA
#
#          hood ac   price
# 0     CollgCr  Y  208500
# 1     Veenker  Y  181500
# 2     CollgCr  Y  223500
# 3     Crawfor  Y  140000
# 4     NoRidge  Y  250000
# ...       ... ..     ...
# 1455  Gilbert  Y  175000
# 1456   NWAmes  Y  210000
# 1457  Crawfor  Y  266500
# 1458    NAmes  Y  142125
# 1459  Edwards  Y  147500
#
# [1330 rows x 12 columns]

# %% [markdown]
# # Visualization in Pandas Dataframe

# %%
clean_df = (df
  .pipe(make_copy)
  .pipe(select_features, features)
  .pipe(fix_names, col_name)
  .pipe(drop_cols, ['utils', 'pool'])
  .pipe(fix_types))

hood_df = (clean_df
    .sort_values(['hood', 'year'])
    .groupby('hood')
    .agg({'area': 'mean', 'price': 'mean'})
)
# Out:
# Shape: (1460, 81), Execution time: 0.38 ms, Function: make_copy
# Shape: (1460, 14), Execution time: 1.10 ms, Function: select_features
# Shape: (1460, 14), Execution time: 0.79 ms, Function: fix_names
# Shape: (1460, 12), Execution time: 0.51 ms, Function: drop_cols
# Shape: (1460, 12), Execution time: 4.69 ms, Function: fix_types

# %%
hood_df
# Out:
#                  area          price
# hood
# Blmngtn   3398.176471  194870.882353
# Blueste   1625.000000  137500.000000
# BrDale    1801.000000  104493.750000
# BrkSide   7360.413793  124834.051724
# ClearCr  30875.750000  212565.428571
# CollgCr   9619.146667  197965.773333
# Crawfor  11809.686275  210624.725490
# Edwards  10218.650000  128219.700000
# Gilbert  11379.151899  192854.506329
# IDOTRR    8109.162162  100123.783784
# MeadowV   2324.000000   98576.470588
# Mitchel  11624.285714  156270.122449
# NAmes    10139.915556  145847.080000
# NPkVill   3267.444444  142694.444444
# NWAmes   11833.630137  189050.068493
# NoRidge  14218.902439  335295.317073
# NridgHt  10887.948052  316270.623377
# OldTown   8207.061947  128225.300885
# SWISU     8127.560000  142591.360000
# Sawyer   10459.283784  136793.135135
# SawyerW   9923.796610  186555.796610
# Somerst   7840.872093  225379.837209
# StoneBr  10671.920000  310499.000000
# Timber   23664.236842  242247.447368
# Veenker  15606.000000  238772.727273

# %% [markdown]
# ## Format text

# %% [markdown]
# [Format Options in Python](https://realpython.com/python-formatted-output/)

# %%
(hood_df
    .style
    .format({'price': '${:,.2f}'})
)
# Out:
# <style  type="text/css" >
# </style><table id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >area</th>        <th class="col_heading level0 col1" >price</th>    </tr>    <tr>        <th class="index_name level0" >hood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row0" class="row_heading level0 row0" >Blmngtn</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row0_col0" class="data row0 col0" >3398.176471</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row0_col1" class="data row0 col1" >$194,870.88</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row1" class="row_heading level0 row1" >Blueste</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row1_col0" class="data row1 col0" >1625.000000</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row1_col1" class="data row1 col1" >$137,500.00</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row2" class="row_heading level0 row2" >BrDale</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row2_col0" class="data row2 col0" >1801.000000</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row2_col1" class="data row2 col1" >$104,493.75</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row3" class="row_heading level0 row3" >BrkSide</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row3_col0" class="data row3 col0" >7360.413793</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row3_col1" class="data row3 col1" >$124,834.05</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row4" class="row_heading level0 row4" >ClearCr</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row4_col0" class="data row4 col0" >30875.750000</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row4_col1" class="data row4 col1" >$212,565.43</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row5" class="row_heading level0 row5" >CollgCr</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row5_col0" class="data row5 col0" >9619.146667</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row5_col1" class="data row5 col1" >$197,965.77</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row6" class="row_heading level0 row6" >Crawfor</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row6_col0" class="data row6 col0" >11809.686275</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row6_col1" class="data row6 col1" >$210,624.73</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row7" class="row_heading level0 row7" >Edwards</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row7_col0" class="data row7 col0" >10218.650000</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row7_col1" class="data row7 col1" >$128,219.70</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row8" class="row_heading level0 row8" >Gilbert</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row8_col0" class="data row8 col0" >11379.151899</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row8_col1" class="data row8 col1" >$192,854.51</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row9" class="row_heading level0 row9" >IDOTRR</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row9_col0" class="data row9 col0" >8109.162162</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row9_col1" class="data row9 col1" >$100,123.78</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row10" class="row_heading level0 row10" >MeadowV</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row10_col0" class="data row10 col0" >2324.000000</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row10_col1" class="data row10 col1" >$98,576.47</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row11" class="row_heading level0 row11" >Mitchel</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row11_col0" class="data row11 col0" >11624.285714</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row11_col1" class="data row11 col1" >$156,270.12</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row12" class="row_heading level0 row12" >NAmes</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row12_col0" class="data row12 col0" >10139.915556</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row12_col1" class="data row12 col1" >$145,847.08</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row13" class="row_heading level0 row13" >NPkVill</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row13_col0" class="data row13 col0" >3267.444444</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row13_col1" class="data row13 col1" >$142,694.44</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row14" class="row_heading level0 row14" >NWAmes</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row14_col0" class="data row14 col0" >11833.630137</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row14_col1" class="data row14 col1" >$189,050.07</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row15" class="row_heading level0 row15" >NoRidge</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row15_col0" class="data row15 col0" >14218.902439</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row15_col1" class="data row15 col1" >$335,295.32</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row16" class="row_heading level0 row16" >NridgHt</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row16_col0" class="data row16 col0" >10887.948052</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row16_col1" class="data row16 col1" >$316,270.62</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row17" class="row_heading level0 row17" >OldTown</th>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row17_col0" class="data row17 col0" >8207.061947</td>
#                         <td id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4row17_col1" class="data row17 col1" >$128,225.30</td>
#             </tr>
#             <tr>
#                         <th id="T_0f9cbe02_ce2e_11ea_8011_9157cf2c11f4level0_row18" class="row_heading level0 row18" >SWISU</th>
#                         <td id="T_0f9cbe02_ce2e_11ea

# %% [markdown]
# ## Style text

# %%
q25 = hood_df.price.quantile(q=0.25)
q75 = hood_df.price.quantile(q=0.75)
box = q75 - q25
L, U = q25 - 1.25 * box, q75 + 1.25 * box

(hood_df
     .style
     .format({'price': '${:,.2f}'}, subset='price')
     .applymap(lambda x: 'color: blue' if (x <= U and x >= L) else 'color: red', subset='price')
)
# Out:
# <style  type="text/css" >
#     #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row0_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row1_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row2_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row3_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row4_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row5_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row6_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row7_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row8_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row9_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row10_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row11_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row12_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row13_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row14_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row15_col1 {
#             color:  red;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row16_col1 {
#             color:  red;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row17_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row18_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row19_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row20_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row21_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row22_col1 {
#             color:  red;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row23_col1 {
#             color:  blue;
#         }    #T_21471a62_ce2e_11ea_8011_9157cf2c11f4row24_col1 {
#             color:  blue;
#         }</style><table id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >area</th>        <th class="col_heading level0 col1" >price</th>    </tr>    <tr>        <th class="index_name level0" >hood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row0" class="row_heading level0 row0" >Blmngtn</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row0_col0" class="data row0 col0" >3398.176471</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row0_col1" class="data row0 col1" >$194,870.88</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row1" class="row_heading level0 row1" >Blueste</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row1_col0" class="data row1 col0" >1625.000000</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row1_col1" class="data row1 col1" >$137,500.00</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row2" class="row_heading level0 row2" >BrDale</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row2_col0" class="data row2 col0" >1801.000000</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row2_col1" class="data row2 col1" >$104,493.75</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row3" class="row_heading level0 row3" >BrkSide</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row3_col0" class="data row3 col0" >7360.413793</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row3_col1" class="data row3 col1" >$124,834.05</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row4" class="row_heading level0 row4" >ClearCr</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row4_col0" class="data row4 col0" >30875.750000</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row4_col1" class="data row4 col1" >$212,565.43</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row5" class="row_heading level0 row5" >CollgCr</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row5_col0" class="data row5 col0" >9619.146667</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row5_col1" class="data row5 col1" >$197,965.77</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row6" class="row_heading level0 row6" >Crawfor</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row6_col0" class="data row6 col0" >11809.686275</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row6_col1" class="data row6 col1" >$210,624.73</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row7" class="row_heading level0 row7" >Edwards</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row7_col0" class="data row7 col0" >10218.650000</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row7_col1" class="data row7 col1" >$128,219.70</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row8" class="row_heading level0 row8" >Gilbert</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row8_col0" class="data row8 col0" >11379.151899</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row8_col1" class="data row8 col1" >$192,854.51</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row9" class="row_heading level0 row9" >IDOTRR</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row9_col0" class="data row9 col0" >8109.162162</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row9_col1" class="data row9 col1" >$100,123.78</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row10" class="row_heading level0 row10" >MeadowV</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row10_col0" class="data row10 col0" >2324.000000</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row10_col1" class="data row10 col1" >$98,576.47</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row11" class="row_heading level0 row11" >Mitchel</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row11_col0" class="data row11 col0" >11624.285714</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row11_col1" class="data row11 col1" >$156,270.12</td>
#             </tr>
#             <tr>
#                         <th id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4level0_row12" class="row_heading level0 row12" >NAmes</th>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row12_col0" class="data row12 col0" >10139.915556</td>
#                         <td id="T_21471a62_ce2e_11ea_8011_9157cf2c11f4row12_col1" class="data row12 col1" >$145,847.08</td>
#             </tr>

# %% [markdown]
# ## Highlight cells & draw bars

# %%
(hood_df
    .style
    .format({
        'price': '${:,.2f}'
    })
    .background_gradient(subset=['price'], cmap='YlGnBu', high=0.5, low=0.)
    .bar(subset=['area'])
    .highlight_min(color='tomato')
    .highlight_max(color='orange')
)
# Out:
# <style  type="text/css" >
#     #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row0_col1 {
#             background-color:  #bbe4b5;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row1_col0 {
#             width:  10em;
#              height:  80%;
#             background-color:  tomato;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row1_col1 {
#             background-color:  #eff9b6;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row2_col1 {
#             background-color:  #fdfed4;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row3_col1 {
#             background-color:  #f5fbc2;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             : ;
#             background-color:  orange;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row4_col1 {
#             background-color:  #9ed9b8;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.3%, transparent 27.3%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row5_col1 {
#             background-color:  #b7e3b6;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.8%, transparent 34.8%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row6_col1 {
#             background-color:  #a2dbb8;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.4%, transparent 29.4%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row7_col1 {
#             background-color:  #f3fabf;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.3%, transparent 33.3%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row8_col1 {
#             background-color:  #c0e6b5;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.2%, transparent 22.2%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row9_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row10_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#             background-color:  tomato;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.2%, transparent 34.2%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row11_col1 {
#             background-color:  #e2f4b2;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.1%, transparent 29.1%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row12_col1 {
#             background-color:  #eaf7b1;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row13_col1 {
#             background-color:  #edf8b2;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.9%, transparent 34.9%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row14_col1 {
#             background-color:  #c4e8b4;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.1%, transparent 43.1%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row15_col1 {
#             background-color:  #1f80b8;
#             color:  #000000;
#             : ;
#             background-color:  orange;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row16_col1 {
#             background-color:  #2195c0;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.5%, transparent 22.5%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row17_col1 {
#             background-color:  #f3fabf;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.2%, transparent 22.2%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row18_col1 {
#             background-color:  #edf8b2;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.2%, transparent 30.2%);
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011_9157cf2c11f4row19_col1 {
#             background-color:  #f0f9b7;
#             color:  #000000;
#             : ;
#             : ;
#         }    #T_28a33b60_ce2e_11ea_8011

# %% [markdown]
# ## Exercise

# %% [markdown]
# Format the area column & add a background gradient
# - 3398.176471 -> 3398 sq.ft

# %%
# YOUR CODE GOES HERE
(hood_df
    .style
    .format({'area': '{:,.0f} sq.ft'})
    .background_gradient(subset=['area']))
# Out:
# <style  type="text/css" >
#     #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row0_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row2_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row3_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row5_col0 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row6_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row7_col0 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row8_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row9_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row10_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row11_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row12_col0 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row13_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row14_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row15_col0 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row16_col0 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row17_col0 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row18_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row19_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row20_col0 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row21_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row22_col0 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row23_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row24_col0 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }</style><table id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >area</th>        <th class="col_heading level0 col1" >price</th>    </tr>    <tr>        <th class="index_name level0" >hood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row0" class="row_heading level0 row0" >Blmngtn</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row0_col0" class="data row0 col0" >3,398 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row0_col1" class="data row0 col1" >194870.882353</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row1" class="row_heading level0 row1" >Blueste</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row1_col0" class="data row1 col0" >1,625 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row1_col1" class="data row1 col1" >137500.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row2" class="row_heading level0 row2" >BrDale</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row2_col0" class="data row2 col0" >1,801 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row2_col1" class="data row2 col1" >104493.750000</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row3" class="row_heading level0 row3" >BrkSide</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row3_col0" class="data row3 col0" >7,360 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row3_col1" class="data row3 col1" >124834.051724</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row4" class="row_heading level0 row4" >ClearCr</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row4_col0" class="data row4 col0" >30,876 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row4_col1" class="data row4 col1" >212565.428571</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row5" class="row_heading level0 row5" >CollgCr</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row5_col0" class="data row5 col0" >9,619 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row5_col1" class="data row5 col1" >197965.773333</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row6" class="row_heading level0 row6" >Crawfor</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row6_col0" class="data row6 col0" >11,810 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row6_col1" class="data row6 col1" >210624.725490</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row7" class="row_heading level0 row7" >Edwards</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row7_col0" class="data row7 col0" >10,219 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row7_col1" class="data row7 col1" >128219.700000</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row8" class="row_heading level0 row8" >Gilbert</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row8_col0" class="data row8 col0" >11,379 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row8_col1" class="data row8 col1" >192854.506329</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row9" class="row_heading level0 row9" >IDOTRR</th>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row9_col0" class="data row9 col0" >8,109 sq.ft</td>
#                         <td id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4row9_col1" class="data row9 col1" >100123.783784</td>
#             </tr>
#             <tr>
#                         <th id="T_2fb18aa6_ce2e_11ea_8011_9157cf2c11f4level0_row10" class="row_heading level0 row10" >MeadowV</th>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Exploratory vs Explanatory data Visualization

# %% [markdown]
# #1 https://gramener.com/mahabharatha/
# #2 https://gramener.com/playground/datacomics/wbl

# %% [markdown]
# [Data Visualization Catalogue](https://datavizproject.com/)

# %% [markdown]
# ## MCQ

# %%
from IPython.display import Image
Image('./bar-chart.png')

# %% [markdown]
# **What is the issue with the above chart?**
# - [] Scale of the bars
# - [] Base of Y axis
# - [] Missing data points
# - [] No Issue

# %%
plt.style.available
# Out:
# ['seaborn-poster',
#  'seaborn-colorblind',
#  'bmh',
#  'seaborn-paper',
#  '_classic_test',
#  'seaborn-whitegrid',
#  'grayscale',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'fast',
#  'seaborn-dark',
#  'Solarize_Light2',
#  'seaborn-pastel',
#  'seaborn-talk',
#  'seaborn-bright',
#  'seaborn-darkgrid',
#  'dark_background',
#  'seaborn-dark-palette',
#  'seaborn-white',
#  'tableau-colorblind10',
#  'classic',
#  'seaborn',
#  'ggplot',
#  'seaborn-deep',
#  'seaborn-notebook',
#  'seaborn-muted']

# %%
plt.style.use('ggplot')
# plt.style.use('seaborn-pastel')

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax.set(title='Figure')
plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(221)
ax1.set(title='1')

ax2 = fig.add_subplot(222)
ax2.set(title='2')

ax3 = fig.add_subplot(223)
ax3.set(title='3')

ax4 = fig.add_subplot(224)
ax4.set(title='4')

plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax.scatter(clean_df.year, clean_df.price, color='k', alpha=0.2)
ax.set(xlabel='Year Built', ylabel='Price in $', title='Price Distribution')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0,0].hist(clean_df.area, bins=20, color='k')
axes[0,0].set_title('Area of property')

axes[0,1].hist(clean_df.year, bins=20, color='k')
axes[0,1].set_title('Year built')

axes[1,0].scatter(clean_df.area, clean_df.price, color='k', alpha=0.2)
axes[1,0].set(xlabel='Area', ylabel='Price')

axes[1,1].scatter(clean_df.year, clean_df.price, color='k', alpha=0.2)
axes[1,1].set(xlabel='Year', ylabel='Price')

plt.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
# Create a Scatter plot between Garage ~ Price

# %%
# YOUR CODE GOES HERE
fig = plt.figure()

ax = fig.add_subplot(111)
ax.scatter(clean_df.garage, clean_df.price, color='k', alpha=0.5)
ax.set_title('Garage vs Price')
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Continuous data

# %%
from itertools import product, repeat, chain

ROW = 2
COL = 6

fig, axes = plt.subplots(nrows=ROW, ncols=COL, figsize=(20,8))
for ((i,j), c) in zip(product(range(ROW), range(COL)), 
                      chain.from_iterable(repeat(clean_df.select_dtypes('number').columns, 2))):
    if i == 0:
        sns.distplot(clean_df[c],
                     bins=10,
                     rug=True,
                     kde=True,
                     ax=axes[i,j])
        axes[i,j].set_xlabel('')
    else:
        sns.boxplot(clean_df[c], orient='h', ax=axes[i,j])
    
fig.suptitle('Distribution of Numerical columns', fontsize=20, fontweight='bold')
plt.show()

# %% [markdown]
# ## Categorical Data

# %%
ROW = 2
COL = 6

fig, axes = plt.subplots(nrows=ROW, ncols=COL, figsize=(26,8))
for ((i,j), c) in zip(product(range(ROW), range(COL)), 
                      chain.from_iterable(repeat(clean_df.select_dtypes('number').columns, 2))):
    if i == 0:
        sns.swarmplot(x='style', y=c, hue='ac', 
                      order=['1Story', '1.5Unf', '1.5Fin', '2Story', '2.5Unf', '2.5Fin', 'SFoyer', 'SLvl'], 
                      data=clean_df, 
                      ax=axes[i,j])
        axes[i,j].set_xlabel('')
        axes[i,j].set_xticklabels(labels=axes[i,j].get_xticklabels(), rotation='45')
    else:
        sns.boxplot(x='style', y=c, hue='ac', 
                    order=['1Story', '1.5Unf', '1.5Fin', '2Story', '2.5Unf', '2.5Fin', 'SFoyer', 'SLvl'], 
                    data=clean_df, 
                    ax=axes[i,j])
        axes[i,j].set_xticklabels(labels=axes[i,j].get_xticklabels(), rotation='45')

# %% [markdown]
# ## Exercise

# %% [markdown]
# Create a swarm plot between hood ~ area of the plot

# %%
# YOUR CODE GOES HERE
fig, ax = plt.subplots(1,1, figsize=(20, 10))

sns.boxplot(x=clean_df.hood, y=clean_df.area, ax=ax, color='tomato')
plt.show()

# %% [markdown]
# ## Bivariate distribution

# %%
sns.jointplot(x='year', y='price', data=clean_df, color='darkslateblue', alpha=0.2)

# %%
sns.jointplot(x='year', y='price', data=clean_df, kind='hex', color='darkslateblue')

# %%
sns.jointplot(x='year', y='price', data=clean_df, kind='kde', color='darkslateblue')

# %%
sns.pairplot(clean_df, hue='condition', palette=sns.color_palette('coolwarm', n_colors=10))
# Out:
# /home/srm/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /home/srm/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /home/srm/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /home/srm/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## MCQ

# %% [markdown]
# Find the odd one out?

# %%
# space & technology
Image('1.png', width=500, height=400)

# %%
# crude oil
Image('2.png', width=500, height=400)

# %%
# spell bee
Image('3.png', width=500, height=400)

# %%
# japanese cars
Image('4.png', width=500, height=400)

# %%
sns.heatmap(clean_df.corr(), cmap='YlGnBu', annot=True)

# %%
# Inccrease the range of correlation
# Add a hook for Explanotory visuals - Data Storytelling
# Move the Piping to previous session
# Design option names that are indicative of the chart
