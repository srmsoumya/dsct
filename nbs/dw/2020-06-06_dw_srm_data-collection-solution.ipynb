# %% [markdown]
# # Data Collection
# <br>
# Given the COVID-19 crisis, we will try to understand the health care capacity for India.
# <br><br>
# <i>The fight against COVID-19 is all about flattening the curve.</i>
# <br>
# <img src='https://thespinoff.co.nz/wp-content/uploads/2020/03/Covid-19-curves-graphic-social-v3.gif' alt='Flatten the curve' width=600 align='left'>

# %% [markdown]
# * **What data do we need to better understand the healthcare capacity of India?**
#     - Discuss

# %% [markdown]
# Now that we understand what data we need to estimate the health care capacity for India. The logical next step is to find relevant data sources.
# Unfortunately, this is not a straight forward process. There are multiple ways in which we can start searching for data sources, here are a few ways to start with:
# 1. Quick google search
# 2. Public [APIs](https://api.covid19india.org/)
# 3. Official websites, in this case [MoHFW](https://www.mohfw.gov.in/) and [ICMR](https://www.icmr.gov.in/)
# 4. Data groups working on similar space [datameet](http://datameet.org/)
# 5. Public feeds like twitter or facebook
# 6. [data.world](https://data.world/)

# %% [markdown]
# **Poll 1: Before we start, how much time do you think a Data Scientist spends in munging the data?**
#     1. [ ] ~30%
#     2. [ ] ~50%
#     3. [ ] ~70%
#     4. [ ] ~90%

# %% [markdown]
# ## Pull Data from an API
#
# Let us now pull the hospital beds data for **India**.
# [COVID 19 API List for India](https://api.rootnet.in/)

# %%
# Import libraries
import requests
import numpy as np
import pandas as pd
from pathlib import Path

pd.options.display.max_rows = 250
pd.options.display.max_columns = 50

# Set data path
DATA = Path('data')
# !ls {DATA}
# Out:
# medical_college_list.csv  nhrr	pneumonia_2018.csv  Poll.docx

# %% [markdown]
# ### Get data from the API

# %%
BED_URL = 'https://api.rootnet.in/covid19-in/hospitals/beds'

r = requests.get(BED_URL)
print(f'Status {r.status_code}')
# Out:
# Status 200

# %% [markdown]
# ### Load it into a `pandas DataFrame`

# %%
api = r.json()

beds = pd.DataFrame(api['data']['regional'])
beds.head()
# Out:
#                state  ruralHospitals  ruralBeds  urbanHospitals  urbanBeds  \
# 0     Andhra Pradesh             193       6480              65      16658
# 1  Arunachal Pradesh             208       2136              10        268
# 2              Assam            1176      10944              50       6198
# 3              Bihar             930       6083             103       5936
# 4       Chhattisgarh             169       5070              45       4342
#
#    totalHospitals  totalBeds                      asOn
# 0             258      23138  2017-01-01T00:00:00.000Z
# 1             218       2404  2017-12-31T00:00:00.000Z
# 2            1226      17142  2017-12-31T00:00:00.000Z
# 3            1033      12019  2016-12-31T00:00:00.000Z
# 4             214       9412  2016-01-01T00:00:00.000Z

# %% [markdown]
# ### State wise bed count

# %%
(beds[:-1][['state', 'totalBeds']]
     .style
     .hide_index()
     .background_gradient(subset='totalBeds', cmap='YlGn'))
# Out:
# <style  type="text/css" >
# #T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow0_col1{
#             background-color:  #cbea9c;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow1_col1{
#             background-color:  #fdfedb;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow2_col1{
#             background-color:  #e1f3a9;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow3_col1{
#             background-color:  #f1fab5;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow4_col1{
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow5_col1{
#             background-color:  #fdfed9;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow6_col1{
#             background-color:  #9fd788;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow7_col1{
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow8_col1{
#             background-color:  #f0f9b4;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow9_col1{
#             background-color:  #f2fab5;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow10_col1{
#             background-color:  #f5fbb8;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow11_col1{
#             background-color:  #006335;
#             color:  #f1f1f1;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow12_col1{
#             background-color:  #7fc97c;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow13_col1{
#             background-color:  #b1df90;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow14_col1{
#             background-color:  #3aa257;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow15_col1{
#             background-color:  #feffe1;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow16_col1,#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow25_col1{
#             background-color:  #fcfed3;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow17_col1,#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow18_col1{
#             background-color:  #feffde;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow19_col1{
#             background-color:  #ddf2a6;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow20_col1{
#             background-color:  #dff3a8;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow21_col1{
#             background-color:  #a1d889;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow22_col1{
#             background-color:  #feffdf;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow23_col1{
#             background-color:  #00482a;
#             color:  #f1f1f1;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow24_col1{
#             background-color:  #d5eea1;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow26_col1{
#             background-color:  #004d2c;
#             color:  #f1f1f1;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow27_col1{
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow28_col1{
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow29_col1{
#             background-color:  #feffe2;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow30_col1,#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow31_col1{
#             background-color:  #ffffe4;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow32_col1,#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow34_col1{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow33_col1{
#             background-color:  #c5e89a;
#             color:  #000000;
#         }#T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow35_col1{
#             background-color:  #fcfed7;
#             color:  #000000;
#         }</style><table id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9d" ><thead>    <tr>        <th class="col_heading level0 col0" >state</th>        <th class="col_heading level0 col1" >totalBeds</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow0_col0" class="data row0 col0" >Andhra Pradesh</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow0_col1" class="data row0 col1" >23138</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow1_col0" class="data row1 col0" >Arunachal Pradesh</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow1_col1" class="data row1 col1" >2404</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow2_col0" class="data row2 col0" >Assam</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow2_col1" class="data row2 col1" >17142</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow3_col0" class="data row3 col0" >Bihar</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow3_col1" class="data row3 col1" >12019</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow4_col0" class="data row4 col0" >Chhattisgarh</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow4_col1" class="data row4 col1" >9412</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow5_col0" class="data row5 col0" >Goa</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow5_col1" class="data row5 col1" >3013</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow6_col0" class="data row6 col0" >Gujarat</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow6_col1" class="data row6 col1" >32280</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow7_col0" class="data row7 col0" >Haryana</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow7_col1" class="data row7 col1" >11240</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow8_col0" class="data row8 col0" >Himachal Pradesh</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow8_col1" class="data row8 col1" >12399</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow9_col0" class="data row9 col0" >Jammu & Kashmir</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow9_col1" class="data row9 col1" >11651</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow10_col0" class="data row10 col0" >Jharkhand</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow10_col1" class="data row10 col1" >10784</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow11_col0" class="data row11 col0" >Karnataka</td>
#                         <td id="T_770b2066_d58f_11ea_a42c_07d49ddb3c9drow11_col1" class="data row11 col1" >70165</td>
#             </tr>
#             <tr>
#                                 <td id="T_770b2066_d58f_1

# %% [markdown]
# ### Exercise 1
#
# 1. Get data for hospital stats at a more granular level. Use the [Medical College API](https://api.rootnet.in/covid19-in/hospitals/medical-colleges)
# 2. Check the status code
# 3. Load the `medicalColleges` data into pandas DataFrame. (Hint: Check the structure of the response before loading it into the DataFrame)
# 4. Find top 5 states with minimum & maximum number of `hospitalBeds`
# 5. Did you notice any difference in number of hospital beds? Can you reason why?

# %%
# 1
COLLEGE_URL = 'https://api.rootnet.in/covid19-in/hospitals/medical-colleges'

# YOUR CODE GOES HERE
r = requests.get(COLLEGE_URL)

# %%
# 2
print(f'Status {r.status_code}')
# Out:
# Status 200

# %%
# 3
college = pd.DataFrame(r.json()['data']['medicalColleges'])
college.head()
# Out:
#             state                                               name  \
# 0   A & N Islands  Andaman & Nicobar Islands Insitute of Medical ...
# 1  Andhra Pradesh            ACSR Government Medical College Nellore
# 2  Andhra Pradesh  Alluri Sitaram Raju Academy of Medical Science...
# 3  Andhra Pradesh              Andhra Medical College, Visakhapatnam
# 4  Andhra Pradesh  Apollo Institute of Medical Sciences and Resea...
#
#             city ownership  admissionCapacity  hospitalBeds
# 0     Port Blair     Govt.                100           460
# 1        Nellore     Govt.                150           750
# 2          Eluru     Trust                150          1070
# 3  Visakhapatnam     Govt.                200          2017
# 4       Chittoor   Society                150             0

# %%
# 4
(college
    .groupby('state')['hospitalBeds']
    .sum()
    .sort_values()
    .head())
# Out:
# state
# Meghalaya          0
# Manipur            0
# Chandigarh         0
# Maharastra         0
# A & N Islands    460
# Name: hospitalBeds, dtype: int64

# %%
# 4
(college
    .groupby('state')['hospitalBeds']
    .sum()
    .sort_values(ascending=False)
    .head())
# Out:
# state
# Karnataka        42656
# Tamil Nadu       38741
# Gujarat          32750
# Uttar Pradesh    25215
# Kerala           22307
# Name: hospitalBeds, dtype: int64

# %%
# 5
college[college.state == 'Maharastra'].head()
# Out:
#           state                                               name       city  \
# 159  Maharastra                        ACPM Medical College, Dhule      Dhule
# 160  Maharastra                 Armed Forces Medical College, Pune       Pune
# 161  Maharastra  Ashwini Rural Medical College, Hospital & Rese...    Solapur
# 162  Maharastra                  B. J. Govt. Medical College, Pune       Pune
# 163  Maharastra  B.K.L Walawalkar Rural Medical College, Ratnagiri  Ratnagiri
#
#     ownership  admissionCapacity  hospitalBeds
# 159     Trust                  0             0
# 160     Govt.                140             0
# 161     Trust                100             0
# 162     Govt.                200             0
# 163     Trust                100             0

# %% [markdown]
# Great, now that we have **# of beds available** in each state, let us extract the **# of corona cases** per state. This will help us to better understand the shortage of beds in the coming future.

# %% [markdown]
# ## Scrape Data from the WEB
#
# We will be scraping the data from Worldometer or Ministry of Health & Family Welfare website.
#
# - [MoHFW](https://www.mohfw.gov.in/)
# - [Worldometer](https://www.worldometers.info/coronavirus/)
#
# > BeautifulSoup - [Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# > Further reading
# - https://do.co/2XzV5uT
# - https://bit.ly/2A2axqo

# %% [markdown]
# ### Get the *source* of the Worldometer or MoHFW webpage

# %%
MOHFW_URL = 'https://www.mohfw.gov.in/'
WORLDOMETER_URL= 'https://www.worldometers.info/coronavirus/'

# %%
india = pd.DataFrame(requests.get('https://www.mohfw.gov.in/data/datanew.json').json())
india.head()
# Out:
#   sno                   state_name active positive  cured death new_active  \
# 0   2  Andaman and Nicobar Islands    403      636    226     7        484
# 1   1               Andhra Pradesh  72188   150209  76614  1407      74404
# 2   3            Arunachal Pradesh    701     1673    969     3        699
# 3   4                        Assam  10183    41726  31442   101      10415
# 4   5                        Bihar  18937    54240  34994   309      20306
#
#   new_positive new_cured new_death state_code
# 0          734       242         8         35
# 1       158764     82886      1474         28
# 2         1698       996         3         12
# 3        42904     32384       105         18
# 4        57024     36389       329         10

# %%
r = requests.get(WORLDOMETER_URL)
print(f'Status: {r.status_code}')
# Out:
# Status: 200

# %% [markdown]
# ### Extract the *table* from the *source*

# %%
# !conda install -y -c conda-forge beautifulsoup4 bs4

# %%
# Import BeautifulSoup
import bs4
from bs4 import BeautifulSoup as BS

page = BS(r.content, 'html.parser')
table = page.select('table#main_table_countries_today')[0]

# %% [markdown]
# ### Look at the underlying structure of the *table*

# %%
table.tbody.tr.select('td')
# Out:
# [<td></td>,
#  <td style="text-align:left;">
#  <nobr>North America</nobr>
#  </td>,
#  <td>5,660,076</td>,
#  <td>+7,902</td>,
#  <td>222,207</td>,
#  <td>+306</td>,
#  <td>2,920,114</td>,
#  <td>+5,166</td>,
#  <td>2,517,755</td>,
#  <td>26,024</td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td data-continent="North America" style="display:none;">North America</td>,
#  <td>
#  </td>,
#  <td></td>,
#  <td></td>]

# %% [markdown]
# ### Extract *data* from the *table*

# %%
from typing import List

def extract_from_table(table: bs4.element.Tag) -> List:
    '''Extracts data from HTML table.
    
    Input:  bs4 *table*
    Return: List of all the values in the table
    '''
    data = list()
    header = list()
    
    # Extract the headers
    for row in table.select('thead tr'):
        header.append([head.text for head in row.select('th')])
    
    # Extract the rows
    for row in table.select('tbody tr'):
        data.append([col.text for col in row.select('td')])
        
    return header, data

header, data_table = extract_from_table(table)

# %%
header[0]
# Out:
# ['#',
#  'Country,Other',
#  'TotalCases',
#  'NewCases',
#  'TotalDeaths',
#  'NewDeaths',
#  'TotalRecovered',
#  'NewRecovered',
#  'ActiveCases',
#  'Serious,Critical',
#  'Tot\xa0Cases/1M pop',
#  'Deaths/1M pop',
#  'TotalTests',
#  'Tests/\n1M pop\n',
#  'Population',
#  'Continent',
#  '1 Caseevery X ppl',
#  '1 Deathevery X ppl',
#  '1 Testevery X ppl']

# %%
data_table[0]
# Out:
# ['',
#  '\nNorth America\n',
#  '5,660,076',
#  '+7,902',
#  '222,207',
#  '+306',
#  '2,920,114',
#  '+5,166',
#  '2,517,755',
#  '26,024',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'North America',
#  '\n',
#  '',
#  '']

# %% [markdown]
# ### Create a `pandas DataFrame` from the *data_table* & fix the `dtypes`

# %%
columns = ['idx', 'country', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_recovered', 
           'new_recovered', 'active_cases', 'critical', 'total_cases_per_million', 'deaths_per_million', 
           'total_tests', 'tests_per_million', 'population', 'continent', '1_case_every_X_ppl', '1_death_every_X_ppl', '1_test_every_X_ppl']
stats = pd.DataFrame(data_table[8:-8], columns=columns)

# %%
stats.head()
# Out:
#   idx       country total_cases new_cases total_deaths new_deaths  \
# 0   1           USA   4,815,776    +2,129     158,376         +11
# 1   2        Brazil   2,733,677                94,130
# 2   3         India   1,819,200   +14,498      38,375        +214
# 3   4        Russia     856,264    +5,394      14,207         +79
# 4   5  South Africa     511,485                 8,366
#
#   total_recovered new_recovered active_cases critical total_cases_per_million  \
# 0       2,380,561          +344    2,276,839   18,623                  14,541
# 1       1,884,051                    755,496    8,318                  12,853
# 2       1,197,512       +10,284      583,313    8,944                   1,317
# 3         653,593        +3,420      188,464    2,300                   5,867
# 4         347,227                    155,892      539                   8,615
#
#   deaths_per_million total_tests tests_per_million      population  \
# 0                478  59,937,617           180,984    331,176,957
# 1                443  13,096,132            61,573    212,694,204
# 2                 28  20,202,858            14,627  1,381,196,835
# 3                 97  29,029,900           198,916    145,940,242
# 4                141   3,036,779            51,147     59,373,395
#
#        continent 1_case_every_X_ppl 1_death_every_X_ppl 1_test_every_X_ppl
# 0  North America                 69               2,091                  6
# 1  South America                 78               2,260                 16
# 2           Asia                759              35,992                 68
# 3         Europe                170              10,272                  5
# 4         Africa                116               7,097                 20

# %%
stats = stats.assign(**{
    'new_cases': pd.to_numeric(stats.new_cases.str.replace(r'[+,]', ''), downcast='integer', errors='coerce'),
    'new_deaths': pd.to_numeric(stats.new_deaths.str.replace(r'[+,]', ''), downcast='integer', errors='coerce'),
    'new_recovered': pd.to_numeric(stats.new_recovered.str.replace(r'[+,]', ''), downcast='integer', errors='coerce')
})

# %% [markdown]
# ### Country wise new cases, deaths & recovery

# %%
(stats
     .filter(['country', 'new_cases', 'new_deaths', 'new_recovered'], axis=1)
     .fillna(0)
     .sort_values(by='new_cases', ascending=False)
     .style
         .format('{:,.0f}', subset=['new_cases', 'new_deaths', 'new_recovered'])
         .background_gradient(subset=['new_cases'], cmap='Oranges')
         .background_gradient(subset=['new_deaths'], cmap='Reds')
         .background_gradient(subset=['new_recovered'], cmap='Greens'))
# Out:
# <style  type="text/css" >
# #T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow0_col1{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow0_col2{
#             background-color:  #c2161b;
#             color:  #f1f1f1;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow0_col3{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow1_col1{
#             background-color:  #fdaf6c;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow1_col2{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow1_col3{
#             background-color:  #aedea7;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow2_col1{
#             background-color:  #fdb97d;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow2_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow2_col3{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow3_col1{
#             background-color:  #fdd5ad;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow3_col2{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow3_col3,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow17_col3{
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow4_col1{
#             background-color:  #fddbb8;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow4_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow7_col2{
#             background-color:  #fcbea5;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow4_col3{
#             background-color:  #cfecc9;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow5_col1{
#             background-color:  #feddbc;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow5_col2{
#             background-color:  #c1161b;
#             color:  #f1f1f1;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow5_col3{
#             background-color:  #d2edcc;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow6_col1{
#             background-color:  #fee2c7;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow6_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow22_col2{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow6_col3,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow12_col3,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow20_col3{
#             background-color:  #f2faf0;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow7_col1{
#             background-color:  #fee7d1;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow7_col3{
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow8_col1{
#             background-color:  #feead5;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow8_col2{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow8_col3,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow16_col3,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow23_col3{
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow9_col1{
#             background-color:  #feead6;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow9_col2{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow9_col3{
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow10_col1{
#             background-color:  #feebd7;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow10_col2{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow10_col3{
#             background-color:  #d5efcf;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow11_col1{
#             background-color:  #feeddb;
#             color:  #000000;
#         }#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow11_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow16_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow19_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow20_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow26_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow29_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow30_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow31_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow32_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow33_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow35_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow36_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow38_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow41_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow43_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow44_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow46_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow49_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow50_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow51_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow52_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow53_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow54_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow55_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow57_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow58_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow59_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow60_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow61_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow62_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow63_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow64_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow65_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow66_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow67_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow68_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow69_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow70_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow72_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow73_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow74_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow75_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow76_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow77_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow78_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow79_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow80_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow81_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow82_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow83_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow84_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow85_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow86_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow87_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow88_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow89_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow90_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow91_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow92_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow93_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow94_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow95_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow96_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow97_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow98_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow99_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow100_col2,#T_7b1f1cd4_d58f_11ea_a42c_07d49ddb3c9drow101_

# %% [markdown]
# ### Exercise 2
#
# Scrape the top section of [MoHFW](https://www.mohfw.gov.in/) page, containing total number of active cases, cured, deaths & migrated.

# %% [markdown]
# **Poll 2: What is unique about the section we are going to scrape in this page?**
#     1. [ ] `div` tag
#     2. [ ] `class=col-xs-12`
#     3. [ ] `class=header-bottom`
#     4. [ ] `ul` tag

# %%
mohfw = requests.get(MOHFW_URL)
page = BS(mohfw.content, 'html.parser')

# %%
# YOUR CODE GOES HERE
section = page.select('div.header-bottom .row .site-meta')
for item in section: print(item.text.strip())
# Out:
# Helpline Number :+91-11-23978046
# Toll Free : 1075
# Helpline Email ID : ncov2019@gov.in
# Covid-19 facilities in States & Union Territories

# %% [markdown]
# Ahh cool! We now have state level cases data & the # of beds available with us. But can we do better?
# Can we get data at District level instead? Let's try!

# %% [markdown]
# ## Parse Data from PDF
#
# We will be parsing the data from [National Health Profile (NHP)](https://www.cbhidghs.nic.in/index7.php?lang=1&level=0&linkid=1086&lid=1107&color=1) reports published by Central Bureau of Health Intelligence (CBHI) every year.

# %% [markdown]
# You can download the PDF from here: [NHP 2019](https://github.com/srmsoumya/dsct/raw/master/data/dw/nhrr/NHRR2019.pdf) & save it in `data` directory

# %% [markdown]
# We will be using Camelot to parse PDF.
# [Camelot](https://camelot-py.readthedocs.io/en/master/)

# %% [markdown]
# ### Extract *medical college data* from NHP 2019 report
#
# > Page [270-282]

# %%
# !conda install -y -c conda-forge camelot-py (not working)
# !pip install camelot-py[cv]

# %%
import camelot

NHRR = DATA/'nhrr'/'NHRR2019.pdf'

# %%
med_clgs = camelot.read_pdf(str(NHRR), pages='270-282', flavor='lattice')

# %%
med_clgs[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 14.29, 'order': 1, 'page': 270}

# %%
med_clgs[0].df
# Out:
#            0                            1  \
# 0   S. \nNo.                     State/UT
# 1          1  Andaman & \nNicobar Islands
# 2          2               Andhra Pradesh
# 3          3
# 4          4
# 5          5
# 6          6
# 7          7
# 8          8
# 9          9
# 10        10
# 11        11
# 12        12
# 13        13
# 14        14
# 15        15
# 16        16
# 17        17
# 18        18
# 19        19
# 20        20
# 21        21
# 22        22
# 23        23
# 24        24
# 25        25
# 26        26
# 27        27
# 28        28
# 29        29
# 30        30
# 31        31
# 32        32
# 33
# 34        33          Arunachal \nPradesh
# 35        34                        Assam
# 36        35
# 37        36
# 38        37
# 39        38
# 40        39
# 41
# 42        40                        Bihar
# 43        41
# 44        42
# 45        43
# 46        44
#
#                                                     2               3  \
# 0                             Name of Medical College       City/Town
# 1   Andaman & Nicobar Islands Insitute of Medical ...      Port Blair
# 2             ACSR Government Medical College Nellore         Nellore
# 3   All India Institute of Medical Sciences, Manga...       Vijaywada
# 4   Alluri Sitaram Raju Academy of Medical Science...           Eluru
# 5               Andhra Medical College, Visakhapatnam   Visakhapatnam
# 6   Apollo Institute of Medical Sciences and Resea...        Chittoor
# 7           Dr. P.S.I. Medical College , Chinoutpalli    Chinoutpalli
# 8           Fathima Instt. of Medical Sciences,Kadapa          Kadapa
# 9   Gayathri Vidya Parishad Institute of Health Ca...   Visakhapatnam
# 10  GITAM Institute of Medical Sciences and Resear...  Visakhapatanam
# 11            Government Medical College, Anantapuram    Anantapurram
# 12   Government Siddhartha Medical College, Vijaywada       Vijaywada
# 13  Great Eastern Medical School and Hospital,Srik...      Srikakulam
# 14                   GSL Medical College, Rajahmundry     Rajahmundry
# 15                     Guntur Medical College, Guntur          Guntur
# 16                     Katuri Medical College, Guntur          Guntur
# 17  Konaseema Institute of Medical Sciences & Rese...      Amalapuram
# 18                   Kurnool Medical College, Kurnool         Kurnool
# 19  Maharajah Institute of Medical Sciences, Vizia...    Vizianagaram
# 20                  Narayana Medical College, Nellore         Nellore
# 21  Nimra Institute of Medical Sciences, Krishna D...   Krishna Dist.
# 22   NRI Institute of Medical Sciences, Visakhapatnam   Visakhapatnam
# 23                        NRI Medical College, Guntur          Guntur
# 24  P E S Institute Of Medical Sciences and Resear...          Kuppam
# 25  Rajiv Gandhi Institute of Medical Sciences, Ka...          Kadapa
# 26  Rajiv Gandhi Institute of Medical Sciences, Sr...      Srikakulam
# 27  Rajiv Gandhi Institute of Medical Sciences,Ong...          Ongole
# 28                Rangaraya Medical College, Kakinada        Kakinada
# 29                      S V Medical College, Tirupati        Tirupati
# 30                 Santhiram Medical College, Nandyal         Nandyal
# 31  SVIM-Sri Padmavathi Medical College for Women,...        Tirupati
# 32             Viswabharathi Medical College, Kurnool         Kurnool
# 33                               Andhra Pradesh Total
# 34  Toma Riba Institute of health & Medical Scienc...      Naharlagun
# 35                   Assam Medical College, Dibrugarh       Dibrugarh
# 36  Fakhruddin Ali Ahmed Medical College, Barpeta,...        Barpeta,
# 37                  Gauhati Medical College, Guwahati        Guwahati
# 38         Jorhat Medical College & Hospital , Jorhat          Jorhat
# 39                   Silchar Medical College, Silchar         Silchar
# 40          Tezpur Medical College & Hospital, Tezpur          Tezpur
# 41                                        Assam Total
# 42  All India Institute of Medical Sciences  Patna...           Patna
# 43       Anugrah Narayan Magadh Medical College, Gaya            Gaya
# 44             Darbhanga Medical College, Lehriasarai     Lehriasarai
# 45                Government Medical College, Bettiah         Bettiah
# 46  Indira Gandhi Institute of Medical Sciences,Sh...           Patna
#
#                   4                     5  \
# 0   Govt/ \nPrivate  Admission \nCapacity
# 1             Govt.                   100
# 2             Govt.                   150
# 3             Govt.                    50
# 4             Trust                   150
# 5             Govt.                   200
# 6           Society                   150
# 7             Trust                   150
# 8             Trust                   100
# 9           Society                   150
# 10       University                     0
# 11            Govt.                   100
# 12            Govt.                   150
# 13            Trust                   100
# 14            Trust                   150
# 15            Govt.                   200
# 16            Trust                   150
# 17            Trust                   150
# 18            Govt.                   200
# 19            Trust                   150
# 20            Trust                   250
# 21          Society                   150
# 22            Trust                   150
# 23            Trust                   200
# 24            Trust                   150
# 25            Govt.                   150
# 26            Govt.                   100
# 27            Govt.                   100
# 28            Govt.                   200
# 29            Govt.                   200
# 30            Trust                   100
# 31            Govt.                   150
# 32          Society                     0
# 33                                   4350
# 34            Govt.                    50
# 35            Govt.                   170
# 36     Govt-Society                   100
# 37            Govt.                   156
# 38            Govt.                   100
# 39            Govt.                   100
# 40            Govt.                   100
# 41                                    726
# 42             Govt                   100
# 43            Govt.                   100
# 44            Govt.                   100
# 45            Govt.                   100
# 46            Govt.                   100
#
#                                            6
# 0   No. of  \nbeds in  \nAttached \nHospital
# 1                                        460
# 2                                        750
# 3                                         NA
# 4                                       1070
# 5                                       2017
# 6                                         NA
# 7                                        398
# 8                                        450
# 9                                         NA
# 10                                        NA
# 11                                       500
# 12                                       412
# 13                                       350
# 14                                      1000
# 15                                      1277
# 16                                       900
# 17                                       879
# 18                                      1050
# 19                                      1050
# 20                                      1550
# 21                                        NA
# 22                                       360
# 23                                      1000
# 24                                       750
# 25                                       750
# 26                                       300
# 27                                       300
# 28                                      1085
# 29                                       862
# 30                                       700
# 31                                       650
# 32                                        NA
# 33                                     20410
# 34                                        NA
# 35                                      1365
# 36                                       500
# 37                                      1982
# 38                                       400
# 39                                       906
# 40                                       500
# 41                                      5653
# 42                                        NA
# 43                                       544
# 44                                      1030
# 45                                       315
# 46                                       500

# %% [markdown]
# ### Clean the table

# %%
def extract_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[0], inplace=True)               # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

med_clgs_df = pd.concat([extract_table(med_clgs[i].df) for i in range(13)])

# %%
# Fill the missing names in `State/UT` column, format the names
med_clgs_df['State/UT'] = med_clgs_df['State/UT'].replace(r'^\s*$', np.nan, regex=True)\
                                                 .ffill()\
                                                 .str.replace('\n', '')

# %%
med_clgs_df.head()
# Out:
#                         State/UT  \
# S.No.
# 1      Andaman & Nicobar Islands
# 2                 Andhra Pradesh
# 3                 Andhra Pradesh
# 4                 Andhra Pradesh
# 5                 Andhra Pradesh
#
#                                  Name of Medical College      City/Town  \
# S.No.
# 1      Andaman & Nicobar Islands Insitute of Medical ...     Port Blair
# 2                ACSR Government Medical College Nellore        Nellore
# 3      All India Institute of Medical Sciences, Manga...      Vijaywada
# 4      Alluri Sitaram Raju Academy of Medical Science...          Eluru
# 5                  Andhra Medical College, Visakhapatnam  Visakhapatnam
#
#       Govt/Private AdmissionCapacity No. of beds in AttachedHospital
# S.No.
# 1            Govt.               100                             460
# 2            Govt.               150                             750
# 3            Govt.                50                              NA
# 4            Trust               150                            1070
# 5            Govt.               200                            2017

# %% [markdown]
# ### Save the data to a CSV file

# %%
med_clgs_df.to_csv(DATA/'medical_college_list.csv', index=False)

# %% [markdown]
# ### *Exercise 3: Take home assignment
#
# Extract **Pneumonia** data from NHP 2019 report
# > Page: [139]

# %%
# YOUR CODE GOES HERE

# %%
pneumonia = camelot.read_pdf(str(NHRR), pages='139', flavor='lattice')

# %%
pneumonia[0].df
# Out:
#            0                  1       2       3       4       5       6  \
# 0   S. \nNo.          State/UT.    Male          Female           Total
# 1                                 Cases  Deaths   Cases  Deaths   Cases
# 2          1     Andhra Pradesh   20203     224   17546     141   37749
# 3          2  Arunachal Pradesh     403       0     304       0     707
# 4          3              Assam   10117      92    6458      43   16575
# 5          4              Bihar   11653      16    8429       9   20082
# 6          5       Chhattisgarh    3506      26    2978      21    6484
# 7          6                Goa    1511      50    1287      24    2798
# 8          7            Gujarat    2847       2    2312       1    5159
# 9          8            Haryana    7843      23    6200      11   14043
# 10         9   Himachal Pradesh    6535      62    6250      45   12785
# 11        10         Jammu Div.    4432       3    4046       6    8478
# 12                 Kashmir Div.    2530       0    2310       0    4840
# 13        11          Jharkhand    1540       2    1219       2    2759
# 14        12          Karnataka   11539      88    9372      54   20911
# 15        13             Kerala    3323      24    3084      20    6407
# 16        14     Madhya Pradesh   31077      64   22902      40   53979
# 17        15        Maharashtra    5513      15    4829      12   10342
# 18        16            Manipur     608       0     478       0    1086
# 19        17          Meghalaya    1914      23    1874      16    3788
# 20        18            Mizoram    1392      23    1182       9    2574
# 21        19           Nagaland     763       0     685       1    1448
# 22        20             Odisha   10251     171    7683     108   17934
# 23        21             Punjab    4988      15    4104       7    9092
# 24        22          Rajasthan   88007      59   63367      39  151374
# 25        23             Sikkim     160       0     127       0     287
# 26        24         Tamil Nadu    6321     489    5541     268   11862
# 27        25          Telangana    3343       2    3222       0    6565
# 28        26            Tripura     721      10     596       7    1317
# 29        27        Uttarakhand    6406       0    5959       0   12365
# 30        28      Uttar Pradesh   89799      71   68457      55  158256
# 31        29        West Bengal  139080     405  127465     255  266545
# 32        30      A & N Islands      81      21      60       2     141
# 33        31         Chandigarh   12704     132    9792      83   22496
# 34        32       D & N Haveli      73      10      65      13     138
# 35        33        Daman & Diu      54       1      37       1      91
# 36        34              Delhi   19794     424   16065     299   35859
# 37        35       Lakshadweep*      24       0      32       0      56
# 38        36         Puducherry     631      47     482      27    1113
# 39                        India  511686    2594  416799    1619  928485
#
#          7
# 0
# 1   Deaths
# 2      365
# 3        0
# 4      135
# 5       25
# 6       47
# 7       74
# 8        3
# 9       34
# 10     107
# 11       9
# 12       0
# 13       4
# 14     142
# 15      44
# 16     104
# 17      27
# 18       0
# 19      39
# 20      32
# 21       1
# 22     279
# 23      22
# 24      98
# 25       0
# 26     757
# 27       2
# 28      17
# 29       0
# 30     126
# 31     660
# 32      23
# 33     215
# 34      23
# 35       2
# 36     723
# 37       0
# 38      74
# 39    4213

# %%
def extract_pneumonia_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Pneumonia Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[[0,1]], inplace=True)                   # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

pneumonia_df = extract_pneumonia_table(pneumonia[0].df)

# %%
pneumonia_df.head()
# Out:
#                State/UT.   Male      Female       Total
# S.No.
# 1         Andhra Pradesh  20203  224  17546  141  37749  365
# 2      Arunachal Pradesh    403    0    304    0    707    0
# 3                  Assam  10117   92   6458   43  16575  135
# 4                  Bihar  11653   16   8429    9  20082   25
# 5           Chhattisgarh   3506   26   2978   21   6484   47

# %%
pneumonia_df.columns = ['State/UT.', 'Male-Cases', 'Male-Deaths', 'Female-Cases', 'Female-Deaths', 'Total-Cases', 'Total-Deaths']

# %%
pneumonia_df.head()
# Out:
#                State/UT. Male-Cases Male-Deaths Female-Cases Female-Deaths  \
# S.No.
# 1         Andhra Pradesh      20203         224        17546           141
# 2      Arunachal Pradesh        403           0          304             0
# 3                  Assam      10117          92         6458            43
# 4                  Bihar      11653          16         8429             9
# 5           Chhattisgarh       3506          26         2978            21
#
#       Total-Cases Total-Deaths
# S.No.
# 1           37749          365
# 2             707            0
# 3           16575          135
# 4           20082           25
# 5            6484           47

# %%
pneumonia_df.to_csv(DATA/'pneumonia_2018.csv', index=False)
