# %% [markdown]
# # Data Collection
# <br>
# Given the COVID-19 crisis, we will try to understand the health care capacity for India.
# <br><br>
# <i>The fight against COVID-19 is all about flattening the curve.</i>
# <br>
# <img src='https://thespinoff.co.nz/wp-content/uploads/2020/03/Covid-19-curves-graphic-social-v3.gif' alt='Flatten the curve' width=600 align='left'>

# %% [markdown]
# ## Pull Data from an API
#
# Let us now pull the hospital beds data for **India**.
# [COVID 19 API List for India](https://api.rootnet.in/)

# %%
# Import libraries
import requests
import numpy as np
import pandas as pd
from pathlib import Path

# Set data path
DATA = Path('data')
# !ls {DATA}
# Out:
# ari_2018.csv	  medical_college_list.csv  nurses.csv		 population.csv
# doctors.csv	  mohfw.csv		    pneumonia_2018.csv
# govt_doctors.csv  nhrr			    pop_by_age_2017.csv

# %% [markdown]
# ### Get data from the API

# %%
BED_URL = 'https://api.rootnet.in/covid19-in/hospitals/beds'

r = requests.get(BED_URL)
print(f'Status {r.status_code}')
# Out:
# Status 200

# %% [markdown]
# ### Load it into a `pandas DataFrame`

# %%
api = r.json()

beds = pd.DataFrame(api['data']['regional'])
beds.head()
# Out:
#                state  ruralHospitals  ruralBeds  urbanHospitals  urbanBeds  \
# 0     Andhra Pradesh             193       6480              65      16658
# 1  Arunachal Pradesh             208       2136              10        268
# 2              Assam            1176      10944              50       6198
# 3              Bihar             930       6083             103       5936
# 4       Chhattisgarh             169       5070              45       4342
#
#    totalHospitals  totalBeds                      asOn
# 0             258      23138  2017-01-01T00:00:00.000Z
# 1             218       2404  2017-12-31T00:00:00.000Z
# 2            1226      17142  2017-12-31T00:00:00.000Z
# 3            1033      12019  2016-12-31T00:00:00.000Z
# 4             214       9412  2016-01-01T00:00:00.000Z

# %% [markdown]
# ### State wise bed count

# %%
(beds[:-1][['state', 'totalBeds']]
     .style
     .hide_index()
     .background_gradient(subset='totalBeds', cmap='YlGn'))
# Out:
# <style  type="text/css" >
#     #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow0_col1 {
#             background-color:  #cbea9c;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow1_col1 {
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow2_col1 {
#             background-color:  #e1f3a9;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow3_col1 {
#             background-color:  #f1fab5;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow4_col1 {
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow5_col1 {
#             background-color:  #fdfed9;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow6_col1 {
#             background-color:  #9fd788;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow7_col1 {
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow8_col1 {
#             background-color:  #f0f9b4;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow9_col1 {
#             background-color:  #f2fab5;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow10_col1 {
#             background-color:  #f5fbb8;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow11_col1 {
#             background-color:  #006335;
#             color:  #f1f1f1;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow12_col1 {
#             background-color:  #7fc97c;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow13_col1 {
#             background-color:  #b1df90;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow14_col1 {
#             background-color:  #3aa257;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow15_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow16_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow17_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow18_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow19_col1 {
#             background-color:  #ddf2a6;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow20_col1 {
#             background-color:  #dff3a8;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow21_col1 {
#             background-color:  #a1d889;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow22_col1 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow23_col1 {
#             background-color:  #00482a;
#             color:  #f1f1f1;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow24_col1 {
#             background-color:  #d5eea1;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow25_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow26_col1 {
#             background-color:  #004d2c;
#             color:  #f1f1f1;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow27_col1 {
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow28_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow29_col1 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow30_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow31_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow32_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow33_col1 {
#             background-color:  #c5e89a;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow34_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow35_col1 {
#             background-color:  #fcfed7;
#             color:  #000000;
#         }</style><table id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00fa" ><thead>    <tr>        <th class="col_heading level0 col0" >state</th>        <th class="col_heading level0 col1" >totalBeds</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow0_col0" class="data row0 col0" >Andhra Pradesh</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow0_col1" class="data row0 col1" >23138</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow1_col0" class="data row1 col0" >Arunachal Pradesh</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow1_col1" class="data row1 col1" >2404</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow2_col0" class="data row2 col0" >Assam</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow2_col1" class="data row2 col1" >17142</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow3_col0" class="data row3 col0" >Bihar</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow3_col1" class="data row3 col1" >12019</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow4_col0" class="data row4 col0" >Chhattisgarh</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow4_col1" class="data row4 col1" >9412</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow5_col0" class="data row5 col0" >Goa</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow5_col1" class="data row5 col1" >3013</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow6_col0" class="data row6 col0" >Gujarat</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow6_col1" class="data row6 col1" >32280</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow7_col0" class="data row7 col0" >Haryana</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow7_col1" class="data row7 col1" >11240</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow8_col0" class="data row8 col0" >Himachal Pradesh</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow8_col1" class="data row8 col1" >12399</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow9_col0" class="data row9 col0" >Jammu & Kashmir</td>
#                         <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow9_col1" class="data row9 col1" >11651</td>
#             </tr>
#             <tr>
#                                 <td id="T_0bb8dd4c_a936_11ea_be9e_a86daa0a00farow10_col0" class="data row10 col0" >Jharkhand</t

# %% [markdown]
# ### Exercise 1
#
# 1. Find top 5 states with maximum number of hospital beds?
# 2. Find top 10 states with least number of rural beds?
# ***
# * Hint: Remember there is a total row in the dataframe

# %%
# 1
beds[:-1].sort_values(by='totalBeds', ascending=False).head(5)
# Out:
#             state  ruralHospitals  ruralBeds  urbanHospitals  urbanBeds  \
# 28    West Bengal            1272      19684             294      58882
# 23     Tamil Nadu             692      40179             525      37353
# 26  Uttar Pradesh            4442      39104             193      37156
# 11      Karnataka            2471      21072             374      49093
# 14    Maharashtra             273      12398             438      39048
#
#     totalHospitals  totalBeds                      asOn
# 28            1566      78566  2015-01-01T00:00:00.000Z
# 23            1217      77532  2017-12-31T00:00:00.000Z
# 26            4635      76260  2017-12-31T00:00:00.000Z
# 11            2845      70165  2017-12-31T00:00:00.000Z
# 14             711      51446  2015-12-31T00:00:00.000Z

# %%
# 2
beds[:-1].sort_values(by='ruralBeds', ascending=True).head(10)
# Out:
#                         state  ruralHospitals  ruralBeds  urbanHospitals  \
# 33                      Delhi               0          0             109
# 30                 Chandigarh               0          0               4
# 35                 Puducherry               3         96              11
# 32                Daman & Diu               5        240               0
# 22                     Sikkim              24        260               9
# 31       Dadra & Nagar Haveli              10        273               1
# 34                Lakshadweep               9        300               0
# 29  Andaman & Nicobar Islands              27        575               3
# 17                    Mizoram              56        604              34
# 18                   Nagaland              21        630              15
#
#     urbanBeds  totalHospitals  totalBeds                      asOn
# 33      24383             109      24383  2015-01-01T00:00:00.000Z
# 30        778               4        778  2016-12-31T00:00:00.000Z
# 35       3473              14       3569  2016-01-01T00:00:00.000Z
# 32          0               5        240  2015-12-31T00:00:00.000Z
# 22       1300              33       1560  2017-12-31T00:00:00.000Z
# 31        316              11        589  2017-12-31T00:00:00.000Z
# 34          0               9        300  2016-01-01T00:00:00.000Z
# 29        500              30       1075  2016-12-31T00:00:00.000Z
# 17       1393              90       1997  2017-12-31T00:00:00.000Z
# 18       1250              36       1880  2015-12-31T00:00:00.000Z

# %% [markdown]
# ### Exercise 2
#
# 1. Get data for hospital stats at a more granular level. Use the [Medical College API](https://api.rootnet.in/covid19-in/hospitals/medical-colleges)
# 2. Check the status code
# 3. Load the `medicalColleges` data into pandas DataFrame. (Hint: Check the structure of the response before loading it into the DataFrame)
# 4. Find top 5 states with minimum & maximum number of `hospitalBeds`
# 5. Did you notice any difference in number of hospital beds? Can you reason why?

# %%
# 1
COLLEGE_URL = 'https://api.rootnet.in/covid19-in/hospitals/medical-colleges'

# YOUR CODE GOES HERE
r = requests.get(COLLEGE_URL)
# Out:
# Status 200
#             state                                               name  \
# 0   A & N Islands  Andaman & Nicobar Islands Insitute of Medical ...
# 1  Andhra Pradesh            ACSR Government Medical College Nellore
# 2  Andhra Pradesh  Alluri Sitaram Raju Academy of Medical Science...
# 3  Andhra Pradesh              Andhra Medical College, Visakhapatnam
# 4  Andhra Pradesh  Apollo Institute of Medical Sciences and Resea...
#
#             city ownership  admissionCapacity  hospitalBeds
# 0     Port Blair     Govt.                100           460
# 1        Nellore     Govt.                150           750
# 2          Eluru     Trust                150          1070
# 3  Visakhapatnam     Govt.                200          2017
# 4       Chittoor   Society                150             0

# %%
# 2
print(f'Status {r.status_code}')

# %%
# 3
college = pd.DataFrame(r.json()['data']['medicalColleges'])
college.head()
# Out:
#             state                                               name  \
# 0   A & N Islands  Andaman & Nicobar Islands Insitute of Medical ...
# 1  Andhra Pradesh            ACSR Government Medical College Nellore
# 2  Andhra Pradesh  Alluri Sitaram Raju Academy of Medical Science...
# 3  Andhra Pradesh              Andhra Medical College, Visakhapatnam
# 4  Andhra Pradesh  Apollo Institute of Medical Sciences and Resea...
#
#             city ownership  admissionCapacity  hospitalBeds
# 0     Port Blair     Govt.                100           460
# 1        Nellore     Govt.                150           750
# 2          Eluru     Trust                150          1070
# 3  Visakhapatnam     Govt.                200          2017
# 4       Chittoor   Society                150             0

# %%
# 4
(college
    .groupby('state')['hospitalBeds']
    .sum()
    .sort_values()
    .head())
# Out:
# state
# Meghalaya          0
# Manipur            0
# Chandigarh         0
# Maharastra         0
# A & N Islands    460
# Name: hospitalBeds, dtype: int64

# %%
# 4
(college
    .groupby('state')['hospitalBeds']
    .sum()
    .sort_values(ascending=False)
    .head())
# Out:
# state
# Karnataka        42656
# Tamil Nadu       38741
# Gujarat          32750
# Uttar Pradesh    25215
# Kerala           22307
# Name: hospitalBeds, dtype: int64

# %%
# 5
college[college.state == 'Maharastra'].head()
# Out:
#           state                                               name       city  \
# 159  Maharastra                        ACPM Medical College, Dhule      Dhule
# 160  Maharastra                 Armed Forces Medical College, Pune       Pune
# 161  Maharastra  Ashwini Rural Medical College, Hospital & Rese...    Solapur
# 162  Maharastra                  B. J. Govt. Medical College, Pune       Pune
# 163  Maharastra  B.K.L Walawalkar Rural Medical College, Ratnagiri  Ratnagiri
#
#     ownership  admissionCapacity  hospitalBeds
# 159     Trust                  0             0
# 160     Govt.                140             0
# 161     Trust                100             0
# 162     Govt.                200             0
# 163     Trust                100             0

# %% [markdown]
# Great, now that we have **# of beds available** in each state, let us extract the **# of corona cases** per state. This will help us to better understand the shortage of beds in the coming future.

# %% [markdown]
# ## Scrape Data from the WEB
#
# We will be scraping the data from Ministry of Health & Family Welfare website.
#
# [MoHFW](https://www.mohfw.gov.in/)
#
# > BeautifulSoup - [Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# > Further reading
# - https://do.co/2XzV5uT
# - https://bit.ly/2A2axqo

# %% [markdown]
# ### Get the *source* of the MoHFW webpage

# %%
MOHFW_URL = 'https://www.mohfw.gov.in/'

r = requests.get(MOHFW_URL)
print(f'Status: {r.status_code}')
# Out:
# Status: 200

# %% [markdown]
# ### Extract the *table* from the *source*

# %%
# Import BeautifulSoup
import bs4
from bs4 import BeautifulSoup as BS

page = BS(r.content, 'html.parser')
table = page.table

# %% [markdown]
# ### Look at the underlying structure of the *table*

# %%
print(table.tbody.tr.prettify())
# Out:
# <tr>
#  <td>
#   1
#  </td>
#  <td>
#   Andaman and Nicobar Islands
#  </td>
#  <td>
#   0
#  </td>
#  <td>
#   33
#  </td>
#  <td>
#   0
#  </td>
#  <td>
#   33
#  </td>
# </tr>

# %% [markdown]
# ### Extract *data* from the *table*

# %%
from typing import List

def extract_from_table(table: bs4.element.Tag) -> List:
    '''Extracts data from HTML table.
    
    Input:  bs4 *table*
    Return: List of all the values in the table
    '''
    data = list()
    
    for row in table.select('tbody tr'):
        data.append([col.text for col in row.find_all('td')])
        
    return data

data_table = extract_from_table(table)
data_table
# Out:
# [['1', 'Andaman and Nicobar Islands', '0', '33', '0', '33'],
#  ['2', 'Andhra Pradesh', '1817', '2620', '73', '4510'],
#  ['3', 'Arunachal Pradesh', '46', '1', '0', '47'],
#  ['4', 'Assam', '1846', '547', '4', '2397'],
#  ['5', 'Bihar', '2460', '2425', '30', '4915'],
#  ['6', 'Chandigarh', '31', '273', '5', '309'],
#  ['7', 'Chhattisgarh', '653', '266', '4', '923'],
#  ['8', 'Dadar Nagar Haveli', '18', '1', '0', '19'],
#  ['9', 'Delhi', '16229', '10664', '761', '27654'],
#  ['10', 'Goa', '202', '65', '0', '267'],
#  ['11', 'Gujarat', '5057', '13316', '1219', '19592'],
#  ['12', 'Haryana', '1794', '2134', '24', '3952'],
#  ['13', 'Himachal Pradesh', '201', '194', '5', '400'],
#  ['14', 'Jammu and Kashmir', '2302', '1126', '39', '3467'],
#  ['15', 'Jharkhand', '520', '473', '7', '1000'],
#  ['16', 'Karnataka', '3186', '1968', '59', '5213'],
#  ['17', 'Kerala', '1030', '762', '15', '1807'],
#  ['18', 'Ladakh', '50', '48', '1', '99'],
#  ['19', 'Madhya Pradesh', '2721', '6108', '399', '9228'],
#  ['20', 'Maharashtra', '42609', '37390', '2969', '82968'],
#  ['21', 'Manipur', '105', '52', '0', '157'],
#  ['22', 'Meghalaya', '19', '13', '1', '33'],
#  ['23', 'Mizoram', '23', '1', '0', '24'],
#  ['24', 'Nagaland', '107', '0', '0', '107'],
#  ['25', 'Odisha', '1057', '1716', '8', '2781'],
#  ['26', 'Puducherry', '63', '36', '0', '99'],
#  ['27', 'Punjab', '373', '2092', '50', '2515'],
#  ['28', 'Rajasthan', '2599', '7501', '231', '10331'],
#  ['29', 'Sikkim', '7', '0', '0', '7'],
#  ['30', 'Tamil Nadu', '13506', '16395', '251', '30152'],
#  ['31', 'Telengana', '1663', '1710', '123', '3496'],
#  ['32', 'Tripura', '574', '173', '0', '747'],
#  ['33', 'Uttarakhand', '869', '423', '11', '1303'],
#  ['34', 'Uttar Pradesh', '3828', '5648', '257', '9733'],
#  ['35', 'West Bengal', '4236', '3119', '383', '7738'],
#  ['', 'Cases being reassigned to states', '8605', '', '', '8605'],
#  ['', 'Total#', '120406', '\n119293\n', '\n6929\n', '\n246628\n'],
#  ['*(Including foreign Nationals)\n\n'],
#  ['**( more than 70% cases due to comorbidities )\n'],
#  ['#States wise distribution is subject to further verification and reconciliation\n'],
#  ['#Our figures are being reconciled with ICMR']]

# %% [markdown]
# ### Create a `pandas DataFrame` from the *data_table* & fix the `dtypes`

# %%
columns = ['sno', 'state', 'active', 'cured', 'dead', 'total']
stats = pd.DataFrame(data_table[:-6], columns=columns)
stats.dtypes
# Out:
# sno       object
# state     object
# active    object
# cured     object
# dead      object
# total     object
# dtype: object

# %%
stats[['active', 'cured', 'dead', 'total']] = stats[['active', 'cured', 'dead', 'total']].astype(int)

# %% [markdown]
# ### State wise deaths & cured cases

# %%
(stats[['state', 'cured', 'dead']]
     .style
     .hide_index()
     .background_gradient(cmap='YlGn'))
# Out:
# <style  type="text/css" >
#     #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow1_col1 {
#             background-color:  #fbfdce;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow1_col2 {
#             background-color:  #fdfedd;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow2_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow2_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow3_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow3_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow4_col1 {
#             background-color:  #fbfdcf;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow4_col2 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow5_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow5_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow6_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow6_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow7_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow7_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow8_col1 {
#             background-color:  #ccea9d;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow8_col2 {
#             background-color:  #d7efa2;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow9_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow9_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow10_col1 {
#             background-color:  #b3e091;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow10_col2 {
#             background-color:  #9dd688;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow11_col1 {
#             background-color:  #fbfed2;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow11_col2 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow12_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow12_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow13_col1 {
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow13_col2 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow14_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow14_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow15_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow15_col2 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow16_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow16_col2 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow17_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow17_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow18_col1 {
#             background-color:  #eef9b3;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow18_col2 {
#             background-color:  #f5fbb8;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow19_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow19_col2 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow20_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow20_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow21_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow21_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow22_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow22_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow23_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow23_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow24_col1 {
#             background-color:  #fcfed6;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow24_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow25_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow25_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow26_col1 {
#             background-color:  #fbfed2;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow26_col2 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow27_col1 {
#             background-color:  #e5f5ac;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow27_col2 {
#             background-color:  #fafdcb;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow28_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow28_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow29_col1 {
#             background-color:  #92d183;
#             color:  #000000;
#         }    #T_8219dd2a_a93a_11ea_be9e_a86daa0a00farow29_col2 {
#             background-color:  #

# %% [markdown]
# ### Exercise 3
#
# 1. Find the top 5 states where the death rate is high
# 2. Find the top 5 states where the cure rate is high
# 3. Take a deep breath & try to understand the data!
#
# (Extra marks for visualizing the column)

# %%
# 1

stats['dead_rate'] = (stats['dead'] / stats['total'] * 100)
(stats
    .sort_values(by='dead_rate', ascending=False)   
    .head(5)
    .style
    .hide_index()
    .background_gradient(cmap='OrRd', subset='dead_rate')
)
# Out:
# <style  type="text/css" >
#     #T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col6 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col6 {
#             background-color:  #f98455;
#             color:  #000000;
#         }    #T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col6 {
#             background-color:  #fdca94;
#             color:  #000000;
#         }    #T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col6 {
#             background-color:  #fff5e6;
#             color:  #000000;
#         }    #T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col6 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }</style><table id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00fa" ><thead>    <tr>        <th class="col_heading level0 col0" >sno</th>        <th class="col_heading level0 col1" >state</th>        <th class="col_heading level0 col2" >active</th>        <th class="col_heading level0 col3" >cured</th>        <th class="col_heading level0 col4" >dead</th>        <th class="col_heading level0 col5" >total</th>        <th class="col_heading level0 col6" >dead_rate</th>        <th class="col_heading level0 col7" >cured_rate</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col0" class="data row0 col0" >11</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col1" class="data row0 col1" >Gujarat</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col2" class="data row0 col2" >5057</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col3" class="data row0 col3" >13316</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col4" class="data row0 col4" >1219</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col5" class="data row0 col5" >19592</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col6" class="data row0 col6" >6.221927</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow0_col7" class="data row0 col7" >67.966517</td>
#             </tr>
#             <tr>
#                                 <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col0" class="data row1 col0" >35</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col1" class="data row1 col1" >West Bengal</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col2" class="data row1 col2" >4236</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col3" class="data row1 col3" >3119</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col4" class="data row1 col4" >383</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col5" class="data row1 col5" >7738</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col6" class="data row1 col6" >4.949599</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow1_col7" class="data row1 col7" >40.307573</td>
#             </tr>
#             <tr>
#                                 <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col0" class="data row2 col0" >19</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col1" class="data row2 col1" >Madhya Pradesh</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col2" class="data row2 col2" >2721</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col3" class="data row2 col3" >6108</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col4" class="data row2 col4" >399</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col5" class="data row2 col5" >9228</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col6" class="data row2 col6" >4.323797</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow2_col7" class="data row2 col7" >66.189857</td>
#             </tr>
#             <tr>
#                                 <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col0" class="data row3 col0" >20</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col1" class="data row3 col1" >Maharashtra</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col2" class="data row3 col2" >42609</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col3" class="data row3 col3" >37390</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col4" class="data row3 col4" >2969</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col5" class="data row3 col5" >82968</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col6" class="data row3 col6" >3.578488</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow3_col7" class="data row3 col7" >45.065567</td>
#             </tr>
#             <tr>
#                                 <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col0" class="data row4 col0" >31</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col1" class="data row4 col1" >Telengana</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col2" class="data row4 col2" >1663</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col3" class="data row4 col3" >1710</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col4" class="data row4 col4" >123</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col5" class="data row4 col5" >3496</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col6" class="data row4 col6" >3.518307</td>
#                         <td id="T_b6fa7134_a93b_11ea_be9e_a86daa0a00farow4_col7" class="data row4 col7" >48.913043</td>
#             </tr>
#     </tbody></table>

# %%
# 2

stats['cured_rate'] = (stats['cured'] / stats['total'] * 100)
(stats
    .sort_values(by='cured_rate', ascending=False)   
    .head(5)
    .style
    .hide_index()
    .background_gradient(cmap='YlGn', subset='cured_rate')
)
# Out:
# <style  type="text/css" >
#     #T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col7 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col7 {
#             background-color:  #3fa85b;
#             color:  #000000;
#         }    #T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col7 {
#             background-color:  #83cb7d;
#             color:  #000000;
#         }    #T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col7 {
#             background-color:  #f2fab5;
#             color:  #000000;
#         }    #T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }</style><table id="T_b7757dca_a93b_11ea_be9e_a86daa0a00fa" ><thead>    <tr>        <th class="col_heading level0 col0" >sno</th>        <th class="col_heading level0 col1" >state</th>        <th class="col_heading level0 col2" >active</th>        <th class="col_heading level0 col3" >cured</th>        <th class="col_heading level0 col4" >dead</th>        <th class="col_heading level0 col5" >total</th>        <th class="col_heading level0 col6" >dead_rate</th>        <th class="col_heading level0 col7" >cured_rate</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col1" class="data row0 col1" >Andaman and Nicobar Islands</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col3" class="data row0 col3" >33</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col5" class="data row0 col5" >33</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col6" class="data row0 col6" >0.000000</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow0_col7" class="data row0 col7" >100.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col0" class="data row1 col0" >6</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col1" class="data row1 col1" >Chandigarh</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col2" class="data row1 col2" >31</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col3" class="data row1 col3" >273</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col4" class="data row1 col4" >5</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col5" class="data row1 col5" >309</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col6" class="data row1 col6" >1.618123</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow1_col7" class="data row1 col7" >88.349515</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col0" class="data row2 col0" >27</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col1" class="data row2 col1" >Punjab</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col2" class="data row2 col2" >373</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col3" class="data row2 col3" >2092</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col4" class="data row2 col4" >50</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col5" class="data row2 col5" >2515</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col6" class="data row2 col6" >1.988072</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow2_col7" class="data row2 col7" >83.180915</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col0" class="data row3 col0" >28</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col1" class="data row3 col1" >Rajasthan</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col2" class="data row3 col2" >2599</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col3" class="data row3 col3" >7501</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col4" class="data row3 col4" >231</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col5" class="data row3 col5" >10331</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col6" class="data row3 col6" >2.235989</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow3_col7" class="data row3 col7" >72.606718</td>
#             </tr>
#             <tr>
#                                 <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col0" class="data row4 col0" >11</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col1" class="data row4 col1" >Gujarat</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col2" class="data row4 col2" >5057</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col3" class="data row4 col3" >13316</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col4" class="data row4 col4" >1219</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col5" class="data row4 col5" >19592</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col6" class="data row4 col6" >6.221927</td>
#                         <td id="T_b7757dca_a93b_11ea_be9e_a86daa0a00farow4_col7" class="data row4 col7" >67.966517</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Exercise 4
#
# Scrape the top section of [MoHFW](https://www.mohfw.gov.in/) page, containing total number of active cases, cured, deaths & migrated.

# %%
# YOUR CODE GOES HERE

section = page.select('div.site-stats-count')[0]
section
# Out:
# <div class="site-stats-count">
# <ul>
# <li class="bg-blue">
# <img alt="Active Status" src="assets/images/icon-infected.png"/>
# <strong>120406</strong>
# <span>Active Cases</span>
# </li>
# <li class="bg-green">
# <img alt="Inactive Status" src="assets/images/icon-inactive.png"/>
# <strong>119292</strong>
# <span class="mob-hide">Cured / Discharged </span>
# <span class="mob-show">Cured/ </span>
# <span class="mob-show">Discharged </span>
# </li>
# <li class="bg-red">
# <img alt="Death Status" src="assets/images/icon-death.png"/>
# <strong>6929</strong>
# <span>Deaths  </span>
# </li>
# <li class="bg-orange">
# <img alt="Inactive Status" src="assets/images/icon-active.png"/>
# <strong>1</strong>
# <span>Migrated</span>
# </li>
# <li class="icon-dashboard">
# <a class="trigger-advisories" href="#site-advisories"><img alt="Advisories" src="assets/images/icon-advisories.png"/></a>
# <a class="trigger-state" href="#state-data"><img alt="State Data" src="assets/images/icon-state.png"/></a>
# <!--<a class="trigger-graph" href="http://www.mohfw.gov.in/index.php" target="_blank"><img src="assets/images/graph.png" alt="Graphics"></a>-->
# </li>
# </ul>
# <div class="status-update">
# <h2>COVID-19 INDIA <span>as on : 07 June 2020, 08:00 IST (GMT+5:30)</span></h2>
# </div>
# </div>

# %%
counts = []

for item in section.find_all('li')[:4]:
    counts.append((item.strong.text, item.span.text))
    
counts
# Out:
# [('120406', 'Active Cases'),
#  ('119292', 'Cured / Discharged '),
#  ('6929', 'Deaths  '),
#  ('1', 'Migrated')]

# %% [markdown]
# Ahh cool! We now have state level cases data & the # of beds available with us. But can we do better?
# Can we get data at District level instead? Let's try!

# %% [markdown]
# ## Parse Data from PDF
#
# We will be parsing the data from [National Health Profile (NHP)](https://www.cbhidghs.nic.in/index7.php?lang=1&level=0&linkid=1086&lid=1107&color=1) reports published by Central Bureau of Health Intelligence (CBHI) every year.

# %% [markdown]
# You can download the PDF from here: [NHP 2019](https://github.com/srmsoumya/dsct/raw/master/data/dw/nhrr/NHRR2019.pdf) & save it in `data` directory

# %% [markdown]
# We will be using Camelot to parse PDF.
# [Camelot](https://camelot-py.readthedocs.io/en/master/)

# %% [markdown]
# ### Extract *medical college data* from NHP 2019 report
#
# > Page [270-282]

# %%
import camelot

NHRR = DATA/'nhrr'/'NHRR2019.pdf'

# %%
med_clgs = camelot.read_pdf(str(NHRR), pages='270-282', flavor='lattice')

# %%
med_clgs[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 14.29, 'order': 1, 'page': 270}

# %%
med_clgs[0].df
# Out:
#            0                            1  \
# 0   S. \nNo.                     State/UT
# 1          1  Andaman & \nNicobar Islands
# 2          2               Andhra Pradesh
# 3          3
# 4          4
# 5          5
# 6          6
# 7          7
# 8          8
# 9          9
# 10        10
# 11        11
# 12        12
# 13        13
# 14        14
# 15        15
# 16        16
# 17        17
# 18        18
# 19        19
# 20        20
# 21        21
# 22        22
# 23        23
# 24        24
# 25        25
# 26        26
# 27        27
# 28        28
# 29        29
# 30        30
# 31        31
# 32        32
# 33
# 34        33          Arunachal \nPradesh
# 35        34                        Assam
# 36        35
# 37        36
# 38        37
# 39        38
# 40        39
# 41
# 42        40                        Bihar
# 43        41
# 44        42
# 45        43
# 46        44
#
#                                                     2               3  \
# 0                             Name of Medical College       City/Town
# 1   Andaman & Nicobar Islands Insitute of Medical ...      Port Blair
# 2             ACSR Government Medical College Nellore         Nellore
# 3   All India Institute of Medical Sciences, Manga...       Vijaywada
# 4   Alluri Sitaram Raju Academy of Medical Science...           Eluru
# 5               Andhra Medical College, Visakhapatnam   Visakhapatnam
# 6   Apollo Institute of Medical Sciences and Resea...        Chittoor
# 7           Dr. P.S.I. Medical College , Chinoutpalli    Chinoutpalli
# 8           Fathima Instt. of Medical Sciences,Kadapa          Kadapa
# 9   Gayathri Vidya Parishad Institute of Health Ca...   Visakhapatnam
# 10  GITAM Institute of Medical Sciences and Resear...  Visakhapatanam
# 11            Government Medical College, Anantapuram    Anantapurram
# 12   Government Siddhartha Medical College, Vijaywada       Vijaywada
# 13  Great Eastern Medical School and Hospital,Srik...      Srikakulam
# 14                   GSL Medical College, Rajahmundry     Rajahmundry
# 15                     Guntur Medical College, Guntur          Guntur
# 16                     Katuri Medical College, Guntur          Guntur
# 17  Konaseema Institute of Medical Sciences & Rese...      Amalapuram
# 18                   Kurnool Medical College, Kurnool         Kurnool
# 19  Maharajah Institute of Medical Sciences, Vizia...    Vizianagaram
# 20                  Narayana Medical College, Nellore         Nellore
# 21  Nimra Institute of Medical Sciences, Krishna D...   Krishna Dist.
# 22   NRI Institute of Medical Sciences, Visakhapatnam   Visakhapatnam
# 23                        NRI Medical College, Guntur          Guntur
# 24  P E S Institute Of Medical Sciences and Resear...          Kuppam
# 25  Rajiv Gandhi Institute of Medical Sciences, Ka...          Kadapa
# 26  Rajiv Gandhi Institute of Medical Sciences, Sr...      Srikakulam
# 27  Rajiv Gandhi Institute of Medical Sciences,Ong...          Ongole
# 28                Rangaraya Medical College, Kakinada        Kakinada
# 29                      S V Medical College, Tirupati        Tirupati
# 30                 Santhiram Medical College, Nandyal         Nandyal
# 31  SVIM-Sri Padmavathi Medical College for Women,...        Tirupati
# 32             Viswabharathi Medical College, Kurnool         Kurnool
# 33                               Andhra Pradesh Total
# 34  Toma Riba Institute of health & Medical Scienc...      Naharlagun
# 35                   Assam Medical College, Dibrugarh       Dibrugarh
# 36  Fakhruddin Ali Ahmed Medical College, Barpeta,...        Barpeta,
# 37                  Gauhati Medical College, Guwahati        Guwahati
# 38         Jorhat Medical College & Hospital , Jorhat          Jorhat
# 39                   Silchar Medical College, Silchar         Silchar
# 40          Tezpur Medical College & Hospital, Tezpur          Tezpur
# 41                                        Assam Total
# 42  All India Institute of Medical Sciences  Patna...           Patna
# 43       Anugrah Narayan Magadh Medical College, Gaya            Gaya
# 44             Darbhanga Medical College, Lehriasarai     Lehriasarai
# 45                Government Medical College, Bettiah         Bettiah
# 46  Indira Gandhi Institute of Medical Sciences,Sh...           Patna
#
#                   4                     5  \
# 0   Govt/ \nPrivate  Admission \nCapacity
# 1             Govt.                   100
# 2             Govt.                   150
# 3             Govt.                    50
# 4             Trust                   150
# 5             Govt.                   200
# 6           Society                   150
# 7             Trust                   150
# 8             Trust                   100
# 9           Society                   150
# 10       University                     0
# 11            Govt.                   100
# 12            Govt.                   150
# 13            Trust                   100
# 14            Trust                   150
# 15            Govt.                   200
# 16            Trust                   150
# 17            Trust                   150
# 18            Govt.                   200
# 19            Trust                   150
# 20            Trust                   250
# 21          Society                   150
# 22            Trust                   150
# 23            Trust                   200
# 24            Trust                   150
# 25            Govt.                   150
# 26            Govt.                   100
# 27            Govt.                   100
# 28            Govt.                   200
# 29            Govt.                   200
# 30            Trust                   100
# 31            Govt.                   150
# 32          Society                     0
# 33                                   4350
# 34            Govt.                    50
# 35            Govt.                   170
# 36     Govt-Society                   100
# 37            Govt.                   156
# 38            Govt.                   100
# 39            Govt.                   100
# 40            Govt.                   100
# 41                                    726
# 42             Govt                   100
# 43            Govt.                   100
# 44            Govt.                   100
# 45            Govt.                   100
# 46            Govt.                   100
#
#                                            6
# 0   No. of  \nbeds in  \nAttached \nHospital
# 1                                        460
# 2                                        750
# 3                                         NA
# 4                                       1070
# 5                                       2017
# 6                                         NA
# 7                                        398
# 8                                        450
# 9                                         NA
# 10                                        NA
# 11                                       500
# 12                                       412
# 13                                       350
# 14                                      1000
# 15                                      1277
# 16                                       900
# 17                                       879
# 18                                      1050
# 19                                      1050
# 20                                      1550
# 21                                        NA
# 22                                       360
# 23                                      1000
# 24                                       750
# 25                                       750
# 26                                       300
# 27                                       300
# 28                                      1085
# 29                                       862
# 30                                       700
# 31                                       650
# 32                                        NA
# 33                                     20410
# 34                                        NA
# 35                                      1365
# 36                                       500
# 37                                      1982
# 38                                       400
# 39                                       906
# 40                                       500
# 41                                      5653
# 42                                        NA
# 43                                       544
# 44                                      1030
# 45                                       315
# 46                                       500

# %% [markdown]
# ### Clean the table

# %%
def extract_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[0], inplace=True)               # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

med_clgs_df = pd.concat([extract_table(med_clgs[i].df) for i in range(13)])

# %%
# Fill the missing names in `State/UT` column, format the names
med_clgs_df['State/UT'] = med_clgs_df['State/UT'].replace(r'^\s*$', np.nan, regex=True)\
                                                 .ffill()\
                                                 .str.replace('\n', '')

# %%
med_clgs_df.head()
# Out:
#                         State/UT  \
# S.No.
# 1      Andaman & Nicobar Islands
# 2                 Andhra Pradesh
# 3                 Andhra Pradesh
# 4                 Andhra Pradesh
# 5                 Andhra Pradesh
#
#                                  Name of Medical College      City/Town  \
# S.No.
# 1      Andaman & Nicobar Islands Insitute of Medical ...     Port Blair
# 2                ACSR Government Medical College Nellore        Nellore
# 3      All India Institute of Medical Sciences, Manga...      Vijaywada
# 4      Alluri Sitaram Raju Academy of Medical Science...          Eluru
# 5                  Andhra Medical College, Visakhapatnam  Visakhapatnam
#
#       Govt/Private AdmissionCapacity No. of beds in AttachedHospital
# S.No.
# 1            Govt.               100                             460
# 2            Govt.               150                             750
# 3            Govt.                50                              NA
# 4            Trust               150                            1070
# 5            Govt.               200                            2017

# %% [markdown]
# ### Save the data to a CSV file

# %%
med_clgs_df.to_csv(DATA/'medical_college_list.csv', index=False)

# %% [markdown]
# ### Exercise 5
#
# Extract **Pneumonia** data from NHP 2019 report
# > Page: [139]

# %%
pneumonia = camelot.read_pdf(str(NHRR), pages='139', flavor='lattice')

# %%
pneumonia[0].df
# Out:
#            0                  1       2       3       4       5       6  \
# 0   S. \nNo.          State/UT.    Male          Female           Total
# 1                                 Cases  Deaths   Cases  Deaths   Cases
# 2          1     Andhra Pradesh   20203     224   17546     141   37749
# 3          2  Arunachal Pradesh     403       0     304       0     707
# 4          3              Assam   10117      92    6458      43   16575
# 5          4              Bihar   11653      16    8429       9   20082
# 6          5       Chhattisgarh    3506      26    2978      21    6484
# 7          6                Goa    1511      50    1287      24    2798
# 8          7            Gujarat    2847       2    2312       1    5159
# 9          8            Haryana    7843      23    6200      11   14043
# 10         9   Himachal Pradesh    6535      62    6250      45   12785
# 11        10         Jammu Div.    4432       3    4046       6    8478
# 12                 Kashmir Div.    2530       0    2310       0    4840
# 13        11          Jharkhand    1540       2    1219       2    2759
# 14        12          Karnataka   11539      88    9372      54   20911
# 15        13             Kerala    3323      24    3084      20    6407
# 16        14     Madhya Pradesh   31077      64   22902      40   53979
# 17        15        Maharashtra    5513      15    4829      12   10342
# 18        16            Manipur     608       0     478       0    1086
# 19        17          Meghalaya    1914      23    1874      16    3788
# 20        18            Mizoram    1392      23    1182       9    2574
# 21        19           Nagaland     763       0     685       1    1448
# 22        20             Odisha   10251     171    7683     108   17934
# 23        21             Punjab    4988      15    4104       7    9092
# 24        22          Rajasthan   88007      59   63367      39  151374
# 25        23             Sikkim     160       0     127       0     287
# 26        24         Tamil Nadu    6321     489    5541     268   11862
# 27        25          Telangana    3343       2    3222       0    6565
# 28        26            Tripura     721      10     596       7    1317
# 29        27        Uttarakhand    6406       0    5959       0   12365
# 30        28      Uttar Pradesh   89799      71   68457      55  158256
# 31        29        West Bengal  139080     405  127465     255  266545
# 32        30      A & N Islands      81      21      60       2     141
# 33        31         Chandigarh   12704     132    9792      83   22496
# 34        32       D & N Haveli      73      10      65      13     138
# 35        33        Daman & Diu      54       1      37       1      91
# 36        34              Delhi   19794     424   16065     299   35859
# 37        35       Lakshadweep*      24       0      32       0      56
# 38        36         Puducherry     631      47     482      27    1113
# 39                        India  511686    2594  416799    1619  928485
#
#          7
# 0
# 1   Deaths
# 2      365
# 3        0
# 4      135
# 5       25
# 6       47
# 7       74
# 8        3
# 9       34
# 10     107
# 11       9
# 12       0
# 13       4
# 14     142
# 15      44
# 16     104
# 17      27
# 18       0
# 19      39
# 20      32
# 21       1
# 22     279
# 23      22
# 24      98
# 25       0
# 26     757
# 27       2
# 28      17
# 29       0
# 30     126
# 31     660
# 32      23
# 33     215
# 34      23
# 35       2
# 36     723
# 37       0
# 38      74
# 39    4213

# %%
def extract_pneumonia_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Pneumonia Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[[0,1]], inplace=True)                   # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

pneumonia_df = extract_pneumonia_table(pneumonia[0].df)

# %%
pneumonia_df.head()
# Out:
#                State/UT.   Male      Female       Total
# S.No.
# 1         Andhra Pradesh  20203  224  17546  141  37749  365
# 2      Arunachal Pradesh    403    0    304    0    707    0
# 3                  Assam  10117   92   6458   43  16575  135
# 4                  Bihar  11653   16   8429    9  20082   25
# 5           Chhattisgarh   3506   26   2978   21   6484   47

# %%
pneumonia_df.columns = ['State/UT.', 'Male-Cases', 'Male-Deaths', 'Female-Cases', 'Female-Deaths', 'Total-Cases', 'Total-Deaths']

# %%
pneumonia_df.head()
# Out:
#                State/UT. Male-Cases Male-Deaths Female-Cases Female-Deaths  \
# S.No.
# 1         Andhra Pradesh      20203         224        17546           141
# 2      Arunachal Pradesh        403           0          304             0
# 3                  Assam      10117          92         6458            43
# 4                  Bihar      11653          16         8429             9
# 5           Chhattisgarh       3506          26         2978            21
#
#       Total-Cases Total-Deaths
# S.No.
# 1           37749          365
# 2             707            0
# 3           16575          135
# 4           20082           25
# 5            6484           47

# %%
pneumonia_df.to_csv(DATA/'pneumonia_2018.csv', index=False)
