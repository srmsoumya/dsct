# %% [markdown]
# # Data Collection
# <br>
# Given the COVID-19 crisis, we will try to understand the health care capacity for India.
# <br><br>
# <i>The fight against COVID-19 is all about flattening the curve.</i>
# <br>
# <img src='https://thespinoff.co.nz/wp-content/uploads/2020/03/Covid-19-curves-graphic-social-v3.gif' alt='Flatten the curve' width=600 align='left'>

# %% [markdown]
# ## Pull Data from an API
#
# Let us now pull the hospital beds data for **India**.
# [COVID 19 API List for India](https://api.rootnet.in/)

# %%
# Import libraries
import requests
import numpy as np
import pandas as pd
from pathlib import Path

# Set data path
DATA = Path('data')
# !ls {DATA}
# Out:
# ari_2018.csv	  medical_college_list.csv  nurses.csv		 population.csv
# doctors.csv	  mohfw.csv		    pneumonia_2018.csv
# govt_doctors.csv  nhrr			    pop_by_age_2017.csv

# %% [markdown]
# ### Get data from the API

# %%
BED_URL = 'https://api.rootnet.in/covid19-in/hospitals/beds'

r = requests.get(BED_URL)
print(f'Status {r.status_code}')
# Out:
# Status 200

# %% [markdown]
# ### Load it into a `pandas DataFrame`

# %%
api = r.json()

beds = pd.DataFrame(api['data']['regional'])
beds.head()
# Out:
#                state  ruralHospitals  ruralBeds  urbanHospitals  urbanBeds  \
# 0     Andhra Pradesh             193       6480              65      16658
# 1  Arunachal Pradesh             208       2136              10        268
# 2              Assam            1176      10944              50       6198
# 3              Bihar             930       6083             103       5936
# 4       Chhattisgarh             169       5070              45       4342
#
#    totalHospitals  totalBeds                      asOn
# 0             258      23138  2017-01-01T00:00:00.000Z
# 1             218       2404  2017-12-31T00:00:00.000Z
# 2            1226      17142  2017-12-31T00:00:00.000Z
# 3            1033      12019  2016-12-31T00:00:00.000Z
# 4             214       9412  2016-01-01T00:00:00.000Z

# %% [markdown]
# ### State wise bed count

# %%
(beds[:-1][['state', 'totalBeds']]
     .style
     .hide_index()
     .background_gradient(subset='totalBeds', cmap='YlGn'))
# Out:
# <style  type="text/css" >
#     #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow0_col1 {
#             background-color:  #cbea9c;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow1_col1 {
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow2_col1 {
#             background-color:  #e1f3a9;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow3_col1 {
#             background-color:  #f1fab5;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow4_col1 {
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow5_col1 {
#             background-color:  #fdfed9;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow6_col1 {
#             background-color:  #9fd788;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow7_col1 {
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow8_col1 {
#             background-color:  #f0f9b4;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow9_col1 {
#             background-color:  #f2fab5;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow10_col1 {
#             background-color:  #f5fbb8;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow11_col1 {
#             background-color:  #006335;
#             color:  #f1f1f1;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow12_col1 {
#             background-color:  #7fc97c;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow13_col1 {
#             background-color:  #b1df90;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow14_col1 {
#             background-color:  #3aa257;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow15_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow16_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow17_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow18_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow19_col1 {
#             background-color:  #ddf2a6;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow20_col1 {
#             background-color:  #dff3a8;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow21_col1 {
#             background-color:  #a1d889;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow22_col1 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow23_col1 {
#             background-color:  #00482a;
#             color:  #f1f1f1;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow24_col1 {
#             background-color:  #d5eea1;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow25_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow26_col1 {
#             background-color:  #004d2c;
#             color:  #f1f1f1;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow27_col1 {
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow28_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow29_col1 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow30_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow31_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow32_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow33_col1 {
#             background-color:  #c5e89a;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow34_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow35_col1 {
#             background-color:  #fcfed7;
#             color:  #000000;
#         }</style><table id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00fa" ><thead>    <tr>        <th class="col_heading level0 col0" >state</th>        <th class="col_heading level0 col1" >totalBeds</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow0_col0" class="data row0 col0" >Andhra Pradesh</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow0_col1" class="data row0 col1" >23138</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow1_col0" class="data row1 col0" >Arunachal Pradesh</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow1_col1" class="data row1 col1" >2404</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow2_col0" class="data row2 col0" >Assam</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow2_col1" class="data row2 col1" >17142</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow3_col0" class="data row3 col0" >Bihar</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow3_col1" class="data row3 col1" >12019</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow4_col0" class="data row4 col0" >Chhattisgarh</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow4_col1" class="data row4 col1" >9412</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow5_col0" class="data row5 col0" >Goa</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow5_col1" class="data row5 col1" >3013</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow6_col0" class="data row6 col0" >Gujarat</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow6_col1" class="data row6 col1" >32280</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow7_col0" class="data row7 col0" >Haryana</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow7_col1" class="data row7 col1" >11240</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow8_col0" class="data row8 col0" >Himachal Pradesh</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow8_col1" class="data row8 col1" >12399</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow9_col0" class="data row9 col0" >Jammu & Kashmir</td>
#                         <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow9_col1" class="data row9 col1" >11651</td>
#             </tr>
#             <tr>
#                                 <td id="T_31cdfad0_a7dd_11ea_91a2_a86daa0a00farow10_col0" class="data row10 col0" >Jharkhand</t

# %% [markdown]
# Great, now that we have **# of beds available** in each state, let us extract the **# of corona cases** per state. This will help us to better understand the shortage of beds in the coming future.

# %% [markdown]
# ## Scrape Data from the WEB
#
# We will be scraping the data from Ministry of Health & Family Welfare website.
#
# [MoHFW](https://www.mohfw.gov.in/)
#
# > BeautifulSoup - [Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# > Further reading
# - https://do.co/2XzV5uT
# - https://bit.ly/2A2axqo

# %% [markdown]
# ### Get the *source* of the MoHFW webpage

# %%
MOHFW_URL = 'https://www.mohfw.gov.in/'

r = requests.get(MOHFW_URL)
print(f'Status: {r.status_code}')
# Out:
# Status: 200

# %% [markdown]
# ### Extract the *table* from the *source*

# %%
# Import BeautifulSoup
import bs4
from bs4 import BeautifulSoup as BS

page = BS(r.content, 'html.parser')
table = page.table

# %% [markdown]
# ### Look at the underlying structure of the *table*

# %%
print(table.tbody.tr.prettify())
# Out:
# <tr>
#  <td>
#   1
#  </td>
#  <td>
#   Andaman and Nicobar Islands
#  </td>
#  <td>
#   0
#  </td>
#  <td>
#   33
#  </td>
#  <td>
#   0
#  </td>
#  <td>
#   33
#  </td>
# </tr>

# %% [markdown]
# ### Extract *data* from the *table*

# %%
from typing import List

def extract_from_table(table: bs4.element.Tag) -> List:
    '''Extracts data from HTML table.
    
    Input:  bs4 *table*
    Return: List of all the values in the table
    '''
    data = list()
    
    for row in table.select('tbody tr'):
        data.append([col.text for col in row.find_all('td')])
        
    return data

data_table = extract_from_table(table)
data_table
# Out:
# [['1', 'Andaman and Nicobar Islands', '0', '33', '0', '33'],
#  ['2', 'Andhra Pradesh', '1654', '2576', '73', '4303'],
#  ['3', 'Arunachal Pradesh', '44', '1', '0', '45'],
#  ['4', 'Assam', '1651', '498', '4', '2153'],
#  ['5', 'Bihar', '2342', '2225', '29', '4596'],
#  ['6', 'Chandigarh', '77', '222', '5', '304'],
#  ['7', 'Chhattisgarh', '633', '244', '2', '879'],
#  ['8', 'Dadar Nagar Haveli', '13', '1', '0', '14'],
#  ['9', 'Delhi', '15311', '10315', '708', '26334'],
#  ['10', 'Goa', '131', '65', '0', '196'],
#  ['11', 'Gujarat', '4901', '13003', '1190', '19094'],
#  ['12', 'Haryana', '1439', '2134', '24', '3597'],
#  ['13', 'Himachal Pradesh', '199', '189', '5', '393'],
#  ['14', 'Jammu and Kashmir', '2202', '1086', '36', '3324'],
#  ['15', 'Jharkhand', '464', '410', '7', '881'],
#  ['16', 'Karnataka', '3090', '1688', '57', '4835'],
#  ['17', 'Kerala', '973', '712', '14', '1699'],
#  ['18', 'Ladakh', '48', '48', '1', '97'],
#  ['19', 'Madhya Pradesh', '2734', '5878', '384', '8996'],
#  ['20', 'Maharashtra', '42224', '35156', '2849', '80229'],
#  ['21', 'Manipur', '91', '41', '0', '132'],
#  ['22', 'Meghalaya', '19', '13', '1', '33'],
#  ['23', 'Mizoram', '21', '1', '0', '22'],
#  ['24', 'Nagaland', '94', '0', '0', '94'],
#  ['25', 'Odisha', '996', '1604', '8', '2608'],
#  ['26', 'Puducherry', '63', '36', '0', '99'],
#  ['27', 'Punjab', '344', '2069', '48', '2461'],
#  ['28', 'Rajasthan', '2507', '7359', '218', '10084'],
#  ['29', 'Sikkim', '3', '0', '0', '3'],
#  ['30', 'Tamil Nadu', '12700', '15762', '232', '28694'],
#  ['31', 'Telengana', '1550', '1627', '113', '3290'],
#  ['32', 'Tripura', '519', '173', '0', '692'],
#  ['33', 'Uttarakhand', '860', '344', '11', '1215'],
#  ['34', 'Uttar Pradesh', '3828', '5648', '257', '9733'],
#  ['35', 'West Bengal', '4025', '2912', '366', '7303'],
#  ['', 'Cases being reassigned to states', '8192', '', '', '8192'],
#  ['', 'Total#', '115942', '\n114073\n', '\n6642\n', '\n236657\n'],
#  ['*(Including foreign Nationals)\n\n'],
#  ['**( more than 70% cases due to comorbidities )\n'],
#  ['#States wise distribution is subject to further verification and reconciliation\n'],
#  ['#Our figures are being reconciled with ICMR']]

# %% [markdown]
# ### Create a `pandas DataFrame` from the *data_table* & fix the `dtypes`

# %%
columns = ['sno', 'state', 'active', 'cured', 'dead', 'total']
stats = pd.DataFrame(data_table[:-6], columns=columns)
stats.dtypes
# Out:
# sno       object
# state     object
# active    object
# cured     object
# dead      object
# total     object
# dtype: object

# %%
stats[['active', 'cured', 'dead', 'total']] = stats[['active', 'cured', 'dead', 'total']].astype(int)

# %% [markdown]
# ### State wise deaths & cured cases

# %%
(stats[['state', 'cured', 'dead']]
     .style
     .hide_index()
     .background_gradient(cmap='YlGn'))
# Out:
# <style  type="text/css" >
#     #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow1_col1 {
#             background-color:  #fafdcc;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow1_col2 {
#             background-color:  #fdfedd;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow2_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow2_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow3_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow3_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow4_col1 {
#             background-color:  #fbfdcf;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow4_col2 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow5_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow5_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow6_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow6_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow7_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow7_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow8_col1 {
#             background-color:  #c9e99c;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow8_col2 {
#             background-color:  #daf0a4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow9_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow9_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow10_col1 {
#             background-color:  #afde8f;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow10_col2 {
#             background-color:  #9cd687;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow11_col1 {
#             background-color:  #fbfed0;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow11_col2 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow12_col1 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow12_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow13_col1 {
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow13_col2 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow14_col1 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow14_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow15_col1 {
#             background-color:  #fcfed4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow15_col2 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow16_col1 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow16_col2 {
#             background-color:  #ffffe4;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow17_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow17_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow18_col1 {
#             background-color:  #edf8b2;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow18_col2 {
#             background-color:  #f5fbb8;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow19_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow19_col2 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow20_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow20_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow21_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow21_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow22_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow22_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow23_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow23_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow24_col1 {
#             background-color:  #fcfed6;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow24_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow25_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow25_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow26_col1 {
#             background-color:  #fbfed0;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow26_col2 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow27_col1 {
#             background-color:  #e3f4aa;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow27_col2 {
#             background-color:  #fafdcb;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow28_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow28_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow29_col1 {
#             background-color:  #8ed082;
#             color:  #000000;
#         }    #T_d0287e04_a7e1_11ea_91a2_a86daa0a00farow29_col2 {
#             background-color:  #

# %% [markdown]
# Ahh cool! We now have state level cases data & the # of beds available with us. But can we do better?
# Can we get data at District level instead? Let's try!

# %% [markdown]
# ## Parse Data from PDF
#
# We will be parsing the data from [National Health Profile (NHP)](https://www.cbhidghs.nic.in/index7.php?lang=1&level=0&linkid=1086&lid=1107&color=1) reports published by Central Bureau of Health Intelligence (CBHI) every year.

# %% [markdown]
# You can download the PDF from here: [NHP 2019](https://github.com/srmsoumya/dsct/raw/master/data/dw/nhrr/NHRR2019.pdf) & save it in `data` directory

# %% [markdown]
# We will be using Camelot to parse PDF.
# [Camelot](https://camelot-py.readthedocs.io/en/master/)

# %% [markdown]
# ### Extract *medical college data* from NHP 2019 report
#
# > Page [270-282]

# %%
import camelot

NHRR = DATA/'nhrr'/'NHRR2019.pdf'

# %%
med_clgs = camelot.read_pdf(str(NHRR), pages='270-282', flavor='lattice')

# %%
med_clgs[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 14.29, 'order': 1, 'page': 270}

# %%
med_clgs[0].df
# Out:
#            0                            1  \
# 0   S. \nNo.                     State/UT
# 1          1  Andaman & \nNicobar Islands
# 2          2               Andhra Pradesh
# 3          3
# 4          4
# 5          5
# 6          6
# 7          7
# 8          8
# 9          9
# 10        10
# 11        11
# 12        12
# 13        13
# 14        14
# 15        15
# 16        16
# 17        17
# 18        18
# 19        19
# 20        20
# 21        21
# 22        22
# 23        23
# 24        24
# 25        25
# 26        26
# 27        27
# 28        28
# 29        29
# 30        30
# 31        31
# 32        32
# 33
# 34        33          Arunachal \nPradesh
# 35        34                        Assam
# 36        35
# 37        36
# 38        37
# 39        38
# 40        39
# 41
# 42        40                        Bihar
# 43        41
# 44        42
# 45        43
# 46        44
#
#                                                     2               3  \
# 0                             Name of Medical College       City/Town
# 1   Andaman & Nicobar Islands Insitute of Medical ...      Port Blair
# 2             ACSR Government Medical College Nellore         Nellore
# 3   All India Institute of Medical Sciences, Manga...       Vijaywada
# 4   Alluri Sitaram Raju Academy of Medical Science...           Eluru
# 5               Andhra Medical College, Visakhapatnam   Visakhapatnam
# 6   Apollo Institute of Medical Sciences and Resea...        Chittoor
# 7           Dr. P.S.I. Medical College , Chinoutpalli    Chinoutpalli
# 8           Fathima Instt. of Medical Sciences,Kadapa          Kadapa
# 9   Gayathri Vidya Parishad Institute of Health Ca...   Visakhapatnam
# 10  GITAM Institute of Medical Sciences and Resear...  Visakhapatanam
# 11            Government Medical College, Anantapuram    Anantapurram
# 12   Government Siddhartha Medical College, Vijaywada       Vijaywada
# 13  Great Eastern Medical School and Hospital,Srik...      Srikakulam
# 14                   GSL Medical College, Rajahmundry     Rajahmundry
# 15                     Guntur Medical College, Guntur          Guntur
# 16                     Katuri Medical College, Guntur          Guntur
# 17  Konaseema Institute of Medical Sciences & Rese...      Amalapuram
# 18                   Kurnool Medical College, Kurnool         Kurnool
# 19  Maharajah Institute of Medical Sciences, Vizia...    Vizianagaram
# 20                  Narayana Medical College, Nellore         Nellore
# 21  Nimra Institute of Medical Sciences, Krishna D...   Krishna Dist.
# 22   NRI Institute of Medical Sciences, Visakhapatnam   Visakhapatnam
# 23                        NRI Medical College, Guntur          Guntur
# 24  P E S Institute Of Medical Sciences and Resear...          Kuppam
# 25  Rajiv Gandhi Institute of Medical Sciences, Ka...          Kadapa
# 26  Rajiv Gandhi Institute of Medical Sciences, Sr...      Srikakulam
# 27  Rajiv Gandhi Institute of Medical Sciences,Ong...          Ongole
# 28                Rangaraya Medical College, Kakinada        Kakinada
# 29                      S V Medical College, Tirupati        Tirupati
# 30                 Santhiram Medical College, Nandyal         Nandyal
# 31  SVIM-Sri Padmavathi Medical College for Women,...        Tirupati
# 32             Viswabharathi Medical College, Kurnool         Kurnool
# 33                               Andhra Pradesh Total
# 34  Toma Riba Institute of health & Medical Scienc...      Naharlagun
# 35                   Assam Medical College, Dibrugarh       Dibrugarh
# 36  Fakhruddin Ali Ahmed Medical College, Barpeta,...        Barpeta,
# 37                  Gauhati Medical College, Guwahati        Guwahati
# 38         Jorhat Medical College & Hospital , Jorhat          Jorhat
# 39                   Silchar Medical College, Silchar         Silchar
# 40          Tezpur Medical College & Hospital, Tezpur          Tezpur
# 41                                        Assam Total
# 42  All India Institute of Medical Sciences  Patna...           Patna
# 43       Anugrah Narayan Magadh Medical College, Gaya            Gaya
# 44             Darbhanga Medical College, Lehriasarai     Lehriasarai
# 45                Government Medical College, Bettiah         Bettiah
# 46  Indira Gandhi Institute of Medical Sciences,Sh...           Patna
#
#                   4                     5  \
# 0   Govt/ \nPrivate  Admission \nCapacity
# 1             Govt.                   100
# 2             Govt.                   150
# 3             Govt.                    50
# 4             Trust                   150
# 5             Govt.                   200
# 6           Society                   150
# 7             Trust                   150
# 8             Trust                   100
# 9           Society                   150
# 10       University                     0
# 11            Govt.                   100
# 12            Govt.                   150
# 13            Trust                   100
# 14            Trust                   150
# 15            Govt.                   200
# 16            Trust                   150
# 17            Trust                   150
# 18            Govt.                   200
# 19            Trust                   150
# 20            Trust                   250
# 21          Society                   150
# 22            Trust                   150
# 23            Trust                   200
# 24            Trust                   150
# 25            Govt.                   150
# 26            Govt.                   100
# 27            Govt.                   100
# 28            Govt.                   200
# 29            Govt.                   200
# 30            Trust                   100
# 31            Govt.                   150
# 32          Society                     0
# 33                                   4350
# 34            Govt.                    50
# 35            Govt.                   170
# 36     Govt-Society                   100
# 37            Govt.                   156
# 38            Govt.                   100
# 39            Govt.                   100
# 40            Govt.                   100
# 41                                    726
# 42             Govt                   100
# 43            Govt.                   100
# 44            Govt.                   100
# 45            Govt.                   100
# 46            Govt.                   100
#
#                                            6
# 0   No. of  \nbeds in  \nAttached \nHospital
# 1                                        460
# 2                                        750
# 3                                         NA
# 4                                       1070
# 5                                       2017
# 6                                         NA
# 7                                        398
# 8                                        450
# 9                                         NA
# 10                                        NA
# 11                                       500
# 12                                       412
# 13                                       350
# 14                                      1000
# 15                                      1277
# 16                                       900
# 17                                       879
# 18                                      1050
# 19                                      1050
# 20                                      1550
# 21                                        NA
# 22                                       360
# 23                                      1000
# 24                                       750
# 25                                       750
# 26                                       300
# 27                                       300
# 28                                      1085
# 29                                       862
# 30                                       700
# 31                                       650
# 32                                        NA
# 33                                     20410
# 34                                        NA
# 35                                      1365
# 36                                       500
# 37                                      1982
# 38                                       400
# 39                                       906
# 40                                       500
# 41                                      5653
# 42                                        NA
# 43                                       544
# 44                                      1030
# 45                                       315
# 46                                       500

# %% [markdown]
# ### Clean the table

# %%
def extract_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[0], inplace=True)               # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

med_clgs_df = pd.concat([extract_table(med_clgs[i].df) for i in range(13)])

# %%
# Fill the missing names in `State/UT` column, format the names
med_clgs_df['State/UT'] = med_clgs_df['State/UT'].replace(r'^\s*$', np.nan, regex=True)\
                                                 .ffill()\
                                                 .str.replace('\n', '')

# %%
med_clgs_df.head()
# Out:
#                         State/UT  \
# S.No.
# 1      Andaman & Nicobar Islands
# 2                 Andhra Pradesh
# 3                 Andhra Pradesh
# 4                 Andhra Pradesh
# 5                 Andhra Pradesh
#
#                                  Name of Medical College      City/Town  \
# S.No.
# 1      Andaman & Nicobar Islands Insitute of Medical ...     Port Blair
# 2                ACSR Government Medical College Nellore        Nellore
# 3      All India Institute of Medical Sciences, Manga...      Vijaywada
# 4      Alluri Sitaram Raju Academy of Medical Science...          Eluru
# 5                  Andhra Medical College, Visakhapatnam  Visakhapatnam
#
#       Govt/Private AdmissionCapacity No. of beds in AttachedHospital
# S.No.
# 1            Govt.               100                             460
# 2            Govt.               150                             750
# 3            Govt.                50                              NA
# 4            Trust               150                            1070
# 5            Govt.               200                            2017

# %% [markdown]
# ### Save the data to a CSV file

# %%
med_clgs_df.to_csv(DATA/'medical_college_list.csv', index=False)

# %% [markdown]
# ### Assignment: Extract **Pneumonia** data from NHP 2019 report
# > Page: [139]

# %%
pneumonia = camelot.read_pdf(str(NHRR), pages='139', flavor='lattice')

# %%
pneumonia[0].df
# Out:
#            0                  1       2       3       4       5       6  \
# 0   S. \nNo.          State/UT.    Male          Female           Total
# 1                                 Cases  Deaths   Cases  Deaths   Cases
# 2          1     Andhra Pradesh   20203     224   17546     141   37749
# 3          2  Arunachal Pradesh     403       0     304       0     707
# 4          3              Assam   10117      92    6458      43   16575
# 5          4              Bihar   11653      16    8429       9   20082
# 6          5       Chhattisgarh    3506      26    2978      21    6484
# 7          6                Goa    1511      50    1287      24    2798
# 8          7            Gujarat    2847       2    2312       1    5159
# 9          8            Haryana    7843      23    6200      11   14043
# 10         9   Himachal Pradesh    6535      62    6250      45   12785
# 11        10         Jammu Div.    4432       3    4046       6    8478
# 12                 Kashmir Div.    2530       0    2310       0    4840
# 13        11          Jharkhand    1540       2    1219       2    2759
# 14        12          Karnataka   11539      88    9372      54   20911
# 15        13             Kerala    3323      24    3084      20    6407
# 16        14     Madhya Pradesh   31077      64   22902      40   53979
# 17        15        Maharashtra    5513      15    4829      12   10342
# 18        16            Manipur     608       0     478       0    1086
# 19        17          Meghalaya    1914      23    1874      16    3788
# 20        18            Mizoram    1392      23    1182       9    2574
# 21        19           Nagaland     763       0     685       1    1448
# 22        20             Odisha   10251     171    7683     108   17934
# 23        21             Punjab    4988      15    4104       7    9092
# 24        22          Rajasthan   88007      59   63367      39  151374
# 25        23             Sikkim     160       0     127       0     287
# 26        24         Tamil Nadu    6321     489    5541     268   11862
# 27        25          Telangana    3343       2    3222       0    6565
# 28        26            Tripura     721      10     596       7    1317
# 29        27        Uttarakhand    6406       0    5959       0   12365
# 30        28      Uttar Pradesh   89799      71   68457      55  158256
# 31        29        West Bengal  139080     405  127465     255  266545
# 32        30      A & N Islands      81      21      60       2     141
# 33        31         Chandigarh   12704     132    9792      83   22496
# 34        32       D & N Haveli      73      10      65      13     138
# 35        33        Daman & Diu      54       1      37       1      91
# 36        34              Delhi   19794     424   16065     299   35859
# 37        35       Lakshadweep*      24       0      32       0      56
# 38        36         Puducherry     631      47     482      27    1113
# 39                        India  511686    2594  416799    1619  928485
#
#          7
# 0
# 1   Deaths
# 2      365
# 3        0
# 4      135
# 5       25
# 6       47
# 7       74
# 8        3
# 9       34
# 10     107
# 11       9
# 12       0
# 13       4
# 14     142
# 15      44
# 16     104
# 17      27
# 18       0
# 19      39
# 20      32
# 21       1
# 22     279
# 23      22
# 24      98
# 25       0
# 26     757
# 27       2
# 28      17
# 29       0
# 30     126
# 31     660
# 32      23
# 33     215
# 34      23
# 35       2
# 36     723
# 37       0
# 38      74
# 39    4213

# %%
def extract_pneumonia_table(df: pd.DataFrame) -> pd.DataFrame:
    '''Cleans the Pneumonia Dataframe'''
    df = df.copy()                                           # Work on a copy
    df.columns = df.iloc[0]                                  # Set Row 1 as the Column
    df.drop(df.index[[0,1]], inplace=True)                   # Delete Row 1
    df.columns = [c.replace(' \n', '') for c in df.columns]  # Format column names
    df = df[df['S.No.'] != '']                               # Remove the total Rows
    df.set_index(keys='S.No.', inplace=True)                 # Set S.No as the index
    
    return df

pneumonia_df = extract_pneumonia_table(pneumonia[0].df)

# %%
pneumonia_df.head()
# Out:
#                State/UT.   Male      Female       Total
# S.No.
# 1         Andhra Pradesh  20203  224  17546  141  37749  365
# 2      Arunachal Pradesh    403    0    304    0    707    0
# 3                  Assam  10117   92   6458   43  16575  135
# 4                  Bihar  11653   16   8429    9  20082   25
# 5           Chhattisgarh   3506   26   2978   21   6484   47

# %%
pneumonia_df.columns = ['State/UT.', 'Male-Cases', 'Male-Deaths', 'Female-Cases', 'Female-Deaths', 'Total-Cases', 'Total-Deaths']

# %%
pneumonia_df.head()
# Out:
#                State/UT. Male-Cases Male-Deaths Female-Cases Female-Deaths  \
# S.No.
# 1         Andhra Pradesh      20203         224        17546           141
# 2      Arunachal Pradesh        403           0          304             0
# 3                  Assam      10117          92         6458            43
# 4                  Bihar      11653          16         8429             9
# 5           Chhattisgarh       3506          26         2978            21
#
#       Total-Cases Total-Deaths
# S.No.
# 1           37749          365
# 2             707            0
# 3           16575          135
# 4           20082           25
# 5            6484           47

# %%
pneumonia_df.to_csv(DATA/'pneumonia_2018.csv', index=False)
